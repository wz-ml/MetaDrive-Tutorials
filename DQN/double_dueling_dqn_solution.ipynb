# %% [markdown]
# ## DDQN Implementation Exercise
# Before beginning this exercise, we highly recommend you read through the [Double DQN Derivation](double_dqn.ipynb) tutorial to get a better grasp of the math behind Double DQN (DDQN).

# %% [markdown]
# Since we've already covered most of this in the DQN exercise, we'll copy all the unchanged code over without explanation. You're encouraged to read through the code again to refresh your memory.

# %%
import metadrive  # Import this package to register the environment!
import gymnasium as gym
from metadrive.envs.top_down_env import TopDownMetaDrive
gym.register(id="MetaDrive-topdown", entry_point=TopDownMetaDrive, kwargs=dict(config={}))
# Out:
# Successfully registered the following environments: ['MetaDrive-validation-v0', 'MetaDrive-10env-v0', 'MetaDrive-100envs-v0', 'MetaDrive-1000envs-v0', 'SafeMetaDrive-validation-v0', 'SafeMetaDrive-10env-v0', 'SafeMetaDrive-100envs-v0', 'SafeMetaDrive-1000envs-v0', 'MARLTollgate-v0', 'MARLBottleneck-v0', 'MARLRoundabout-v0', 'MARLIntersection-v0', 'MARLParkingLot-v0', 'MARLMetaDrive-v0'].

# %%
import numpy as np
import numpy.typing as npt

NUM_ACTIONS = 4

def discrete2continuous(action:int) -> npt.NDArray[np.float32]:
    """
    Convert discrete action to continuous action
    """
    assert 0 <= action < NUM_ACTIONS
    throttle_magnitude = 1.0
    brake_magnitude = 1.0
    steering_magnitude = 1.0
    match action:
        case 0:
            return np.array([steering_magnitude, 0.0])
        case 1:
            return np.array([0.0, throttle_magnitude])
        case 2:
            return np.array([0.0, -brake_magnitude])
        case 3:
            return np.array([-steering_magnitude, 0.0])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Q network
class QNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        # input is size 84x84x5
        # output is size NUM_ACTIONS
        self.conv1 = nn.Conv2d(5, 16, kernel_size=8, stride=4) # 84x84x5 -> 20x20x16
        self.conv2 = nn.Conv2d(16, 32, kernel_size=4, stride=2) # 20x20x16 -> 9x9x32
        self.fc1 = nn.Linear(9*9*32, 256) # 9x9x32 -> 256
        self.fc2 = nn.Linear(256, NUM_ACTIONS) # 256 -> NUM_ACTIONS

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.conv1(x)) # Bx84x84x5 -> Bx20x20x16
        x = F.relu(self.conv2(x)) # Bx20x20x16 -> Bx9x9x32
        x = torch.flatten(x, start_dim=1) # Bx9x9x32 -> Bx9*9*32
        x = F.relu(self.fc1(x)) # Bx9*9*32 -> Bx256
        x = self.fc2(x) # Bx256 -> BxNUM_ACTIONS
        return x

# %%
def obs_batch_to_tensor(obs: list[npt.NDArray[np.float32]], device: torch.device) -> torch.Tensor:
    """
    Reshape the image observation from (B, H, W, C) to (B, C, H, W) and convert it to a tensor
    """
    return torch.tensor(np.stack(obs), dtype=torch.float32, device=device).permute(0, 3, 1, 2)

# %%
def deviceof(m: nn.Module) -> torch.device:
    """
    Get the device of the given module
    """
    return next(m.parameters()).device

class QPolicy:
    def __init__(self, net:QNetwork, epsilon: float = 0.0):
        self.net = net
        self.epsilon = epsilon
    
    def __call__(self, obs: npt.NDArray[np.float32]) -> int:
        """
        Return action given observation
        """
        if np.random.rand() < self.epsilon:
            return np.random.randint(NUM_ACTIONS)
        else:
            device = deviceof(self.net)
            obs_batch = obs_batch_to_tensor([obs], device)
            with torch.no_grad():
                q_values = self.net(obs_batch)[0]
                return torch.argmax(q_values).item()

# %%
import typing

class Transition(typing.NamedTuple):
    obs: npt.NDArray[np.float32]
    action: int
    reward: float
    next_obs: npt.NDArray[np.float32]
    terminated: bool


def collect_trajectory(env:gym.Env, policy:typing.Callable[[npt.NDArray], int]) -> list[Transition]:
    """
    Collect a trajectory from the environment using the given policy
    """
    trajectory = []

    obs, info = env.reset()

    while True:
        action = policy(obs)
        next_obs, reward, terminated, truncated, info = env.step(discrete2continuous(action))
        trajectory.append(Transition(obs, action, reward, next_obs, terminated))
        if terminated or truncated:
            break
        else:
            obs = next_obs

    return trajectory

# %%
import random
class ReplayBuffer():
    def __init__(self, capacity:int = 10000):
        self.capacity = capacity
        self.buffer: list[Transition] = []
        self.position = 0

    def push(self, transition: Transition):
        if len(self.buffer) < self.capacity:
            self.buffer.append(transition)
        else:
            self.buffer[self.position] = transition
        # Overwrite the earliest stuff if the buffer is full.
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size:int) -> list[Transition]:
        return random.sample(self.buffer, batch_size)

    def __len__(self) -> int:
        return len(self.buffer)

# %% [markdown]
# ## Double DQN
#
# *Note: We implement the version of DDQN as described by [Hasselt et al. (2015)](https://arxiv.org/abs/1509.06461).*
#
# The key issue with DQNs (as we saw in the previous exercise) is that the max operation in the target Q value calculation is susceptible to overestimation. To address this issue, DDQN proposes to introduce two separate networks: a **primary network** (denoted by $Q_{\phi}$) and a **target network** (denoted by $Q_{\phi_{\text{target}}}$). The primary network is used for action selection, and the target network is used for action evaluation. The target network is updated less frequently than the action network.
#
# The idea is that the primary network will learn to predict the Q-Values for the policy defined by the target network. This also helps eliminate the moving target problem, since the target network is only updated periodically.
#
# #### DDQN Network Update Rule
#
# For:
# * Terminal pairs: $Q_{\text{target}}(s, a) = r$
# * Non-terminal pairs: $Q_{\text{target}}(s, a) = r + \gamma Q_{\phi_{\text{target}}}(s', \underset{a' \in A}{\operatorname{argmax}} \, Q_{\phi}(s', a'))$
#
# We train the primary network to more closely match the target q-values by minimizing the following loss function:
# $$
# \mathcal{L}(\phi) = \mathbb{E}_{s, a, r, s'} \left[ \left( Q_{\phi}(s, a) - Q_{\text{target}}(s, a) \right)^2 \right]
# $$

# %%
def compute_target_q_values(
        primary_q_network: QNetwork,
        target_q_network: QNetwork,
        rewards: list[float],
        next_observations: list[npt.NDArray[np.float32]],
        terminateds: list[bool],
        gamma: float
) -> list[float]:
    """
    Compute the target Q values for the transitions
    """
    # assert that the lengths of the lists are the same
    n_transitions = len(rewards)
    assert len(next_observations) == n_transitions
    assert len(terminateds) == n_transitions

    # assert that primary and target networks are on the same device
    device = deviceof(primary_q_network)
    assert deviceof(target_q_network) == device

    # compute the Q_target(s', a') values
    next_obs_batch = obs_batch_to_tensor(next_observations, device)
    with torch.no_grad():
        primary_next_q_values = primary_q_network(next_obs_batch)
        target_next_q_values = target_q_network(next_obs_batch)

    # compute argmax_a' Q_phi(s', a') for each transition
    argmax_next_q_values = torch.max(primary_next_q_values, dim=1).indices

    # compute the Q_phi_target(s', argmax_a' Q_phi(s', a')) values
    max_next_q_values = target_next_q_values[range(n_transitions), argmax_next_q_values]
    
    # compute the target Q values
    target_q_values = []
    for reward, terminated, max_next_q_value in zip(rewards, terminateds, max_next_q_values):
        if terminated:
            target_q_values.append(reward)
        else:
            target_q_values.append(reward + gamma * float(max_next_q_value))

    return target_q_values

# %% [markdown]
# We train the Q-Network to try to predict these target Q values. We use MSE loss to train the network, but another popular choice is Huber loss.

# %%
def train_primary_q_network(
        primary_q_network: QNetwork,
        target_q_network: QNetwork,
        optimizer: torch.optim.Optimizer,
        transitions: list[Transition],
        gamma: float
) -> float:
    """
    Train the Q network using the given transitions
    """
    # unpack the transitions
    obs_batch, action_batch, reward_batch, next_obs_batch, terminated_batch = zip(*transitions)
    
    device = deviceof(primary_q_network)

    # compute the target Q values
    target_q_values = compute_target_q_values(primary_q_network, target_q_network, reward_batch, next_obs_batch, terminated_batch, gamma)
    target_q_values_tensor = torch.tensor(target_q_values, dtype=torch.float32, device=device)

    # compute the Q values for the picked actions
    obs_batch = obs_batch_to_tensor(obs_batch, device)
    all_q_values = primary_q_network(obs_batch)
    q_values = all_q_values[range(len(action_batch)), action_batch]

    # compute the loss
    loss = F.mse_loss(q_values, target_q_values_tensor)

    # perform gradient descent
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return float(loss)

def soft_update_target_q_network(primary_q_network: QNetwork, target_q_network: QNetwork, tau: float):
    """
    Soft update the target Q network
    """
    # assert that primary and target networks are on the same device
    device = deviceof(primary_q_network)
    assert deviceof(target_q_network) == device

    # update the target network parameters
    for primary_param, target_param in zip(primary_q_network.parameters(), target_q_network.parameters()):
        target_param.data.copy_(tau * primary_param.data + (1 - tau) * target_param.data)

# %% [markdown]
# ## Implementing a Double Dueling DQN
# That's right! We can stack both improvements on top of each other to achieve unparalleled performance (for what you've learned so far). As the methodologies are independent, we can implement both **advantage-value separation** and primary/target network separation simultaneously.
#
# Recall from the [Double/Dueling DQN Notebook](double_and_dueling_dqn.ipynb) that our Q-value function can be broken down into the advantage function (which takes in a state-action pair) and the value function (which takes in a state).
# $$Q^{\pi}(s,a) = A^{\pi}(s, a) + V^{\pi}(s)$$
#
# We also went over how we might implement an advantage function and a value function simultaneously within the same network by creating two heads. Let's do that below:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Q network for a dueling dqn
class QNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        # input is size 84x84x5
        # output is size NUM_ACTIONS
        self.conv1 = nn.Conv2d(5, 16, kernel_size=8, stride=4) # 84x84x5 -> 20x20x16
        self.conv2 = nn.Conv2d(16, 32, kernel_size=4, stride=2) # 20x20x16 -> 9x9x32
        self.fc1 = nn.Linear(9*9*32, 256) # 9x9x32 -> 256
        self.advantage_head = nn.Linear(256, NUM_ACTIONS) # 256 -> NUM_ACTIONS
        self.value_head = nn.Linear(256, 1) # 256 -> 1

# %% [markdown]
# Recall how we calculate our Q-value:
# $$Q^{\pi}(s,a) = V^{\pi}(s) + \left[A^{\pi}(s, a) - \frac{1}{|A|}\ \underset{a \in A}{\sum} \space A^{\pi}(s, a)\right]$$

# %%
def forward(self, x: torch.Tensor) -> torch.Tensor:
    x = F.relu(self.conv1(x)) # Bx84x84x5 -> Bx20x20x16
    x = F.relu(self.conv2(x)) # Bx20x20x16 -> Bx9x9x32
    x = torch.flatten(x, start_dim=1) # Bx9x9x32 -> Bx9*9*32
    x = F.relu(self.fc1(x)) # Bx9*9*32 -> Bx256
    advantage = self.advantage_head(x) # Bx256 -> BxNUM_ACTIONS
    value = self.value_head(x) # Bx256 -> Bx1
    return value + advantage - advantage.mean(dim=1, keepdim=True)
QNetwork.forward = forward

# %% [markdown]
# ### Training Loop

# %% [markdown]
# Now, we can finally begin training the network.

# %%
# disable logging from metadrive
import logging
import inspect
import metadrive.envs.top_down_env
logging.getLogger(inspect.getfile(metadrive.envs.base_env)).setLevel(logging.WARNING)

# %%
def set_lr(optimizer: torch.optim.Optimizer, lr: float) -> None:
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

primary_q_network = QNetwork().to(device)
target_q_network = QNetwork().to(device)

q_optimizer = torch.optim.Adam(primary_q_network.parameters())

policy = QPolicy(primary_q_network, epsilon=0.3)

replay_buffer = ReplayBuffer()

step = 0
returns = []
losses = []

# %%
env = gym.make("MetaDrive-topdown", config={"use_render": False, "horizon": 300, "num_scenarios": 100})
# Out:
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:29: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: float32. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:34: UserWarning: WARN: It seems a Box observation space is an image but the lower and upper bounds are not [0, 255]. Actual lower bound: -0.0, upper bound: 1.0. Generally, CNN policies assume observations are within that range, so you may encounter an issue if the observation values are not.
#   logger.warn(

# %%
TRAIN_EPOCHS = 1000
EPISODES_PER_BATCH = 16
UPDATE_TO_COLLECT_RATIO = 1.0
GAMMA = 0.80
TAU = 0.01
set_lr(q_optimizer, 1e-4)

# Train
while step < TRAIN_EPOCHS:
    trajectory_returns = []

    for _ in range(EPISODES_PER_BATCH):
        # Collect trajectory
        transitions = collect_trajectory(env, policy)
        rew_traj = [t.reward for t in transitions]

        # Update replay buffer
        for t in transitions:
            replay_buffer.push(t)

        # Update trajectory returns
        trajectory_returns.append(sum(rew_traj))

    loss = train_primary_q_network(
        primary_q_network,
        target_q_network,
        q_optimizer,
        replay_buffer.sample(round(EPISODES_PER_BATCH * UPDATE_TO_COLLECT_RATIO)),
        GAMMA
    )
    soft_update_target_q_network(primary_q_network, target_q_network, TAU)

    # slowly decay the epsilon
    policy.epsilon = policy.epsilon * 0.998

    # collect statistics
    returns.append(trajectory_returns)
    losses.append(loss)

    print(f"Step {step}, Avg. Returns: {np.mean(trajectory_returns):.3f} +/- {np.std(trajectory_returns):.3f}, Median: {np.median(trajectory_returns):.3f}, Q-Network Loss: {losses[-1]:.3f}")

    step += 1
# Out:
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:210: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# Step 0, Avg. Returns: -0.409 +/- 0.226, Median: -0.434, Q-Network Loss: 0.001
# Step 1, Avg. Returns: 1.119 +/- 1.534, Median: 1.265, Q-Network Loss: 0.000
# Step 2, Avg. Returns: 0.983 +/- 2.182, Median: 1.806, Q-Network Loss: 0.001
# Step 3, Avg. Returns: 0.315 +/- 2.393, Median: 1.390, Q-Network Loss: 0.001
# Step 4, Avg. Returns: -0.211 +/- 2.418, Median: 1.092, Q-Network Loss: 0.001
# Step 5, Avg. Returns: 0.426 +/- 2.089, Median: 1.167, Q-Network Loss: 0.003
# Step 6, Avg. Returns: 0.078 +/- 2.612, Median: 1.597, Q-Network Loss: 0.002
# Step 7, Avg. Returns: -0.818 +/- 2.709, Median: 1.007, Q-Network Loss: 0.001
# Step 8, Avg. Returns: 0.223 +/- 2.260, Median: 1.337, Q-Network Loss: 0.001
# Step 9, Avg. Returns: -0.533 +/- 2.637, Median: 1.073, Q-Network Loss: 0.001
# Step 10, Avg. Returns: -0.477 +/- 2.641, Median: 1.089, Q-Network Loss: 0.001
# Step 11, Avg. Returns: 0.762 +/- 1.760, Median: 1.237, Q-Network Loss: 0.001
# Step 12, Avg. Returns: 0.495 +/- 2.175, Median: 1.424, Q-Network Loss: 0.001
# Step 13, Avg. Returns: -0.762 +/- 2.775, Median: 0.924, Q-Network Loss: 0.000
# Step 14, Avg. Returns: -0.151 +/- 2.559, Median: 1.240, Q-Network Loss: 0.000
# Step 15, Avg. Returns: 1.213 +/- 1.345, Median: 1.508, Q-Network Loss: 0.001
# Step 16, Avg. Returns: 0.553 +/- 2.186, Median: 1.502, Q-Network Loss: 0.000
# Step 17, Avg. Returns: 0.551 +/- 2.039, Median: 1.314, Q-Network Loss: 0.001
# Step 18, Avg. Returns: 1.013 +/- 1.913, Median: 1.373, Q-Network Loss: 0.001
# Step 19, Avg. Returns: -1.733 +/- 2.686, Median: -3.751, Q-Network Loss: 0.001
# Step 20, Avg. Returns: -0.012 +/- 2.585, Median: 1.349, Q-Network Loss: 0.000
# Step 21, Avg. Returns: 0.767 +/- 1.792, Median: 1.240, Q-Network Loss: 0.000
# Step 22, Avg. Returns: -0.175 +/- 2.460, Median: 1.187, Q-Network Loss: 0.000
# Step 23, Avg. Returns: -0.102 +/- 2.504, Median: 1.370, Q-Network Loss: 0.000
# Step 24, Avg. Returns: 0.480 +/- 2.054, Median: 1.352, Q-Network Loss: 0.000
# Step 25, Avg. Returns: -0.141 +/- 2.531, Median: 1.039, Q-Network Loss: 0.000
# Step 26, Avg. Returns: 0.049 +/- 3.557, Median: 0.922, Q-Network Loss: 1.539
# Step 27, Avg. Returns: 27.236 +/- 28.462, Median: 15.777, Q-Network Loss: 0.006
# Step 28, Avg. Returns: 41.717 +/- 30.004, Median: 48.816, Q-Network Loss: 0.000
# Step 29, Avg. Returns: 46.428 +/- 29.999, Median: 46.429, Q-Network Loss: 1.584
# Step 30, Avg. Returns: 67.186 +/- 46.325, Median: 60.541, Q-Network Loss: 0.265
# Step 31, Avg. Returns: 65.438 +/- 41.876, Median: 59.834, Q-Network Loss: 0.962
# Step 32, Avg. Returns: 50.816 +/- 34.150, Median: 52.186, Q-Network Loss: 0.685
# Step 33, Avg. Returns: 53.654 +/- 55.113, Median: 29.155, Q-Network Loss: 1.984
# Step 34, Avg. Returns: 67.017 +/- 37.306, Median: 72.228, Q-Network Loss: 0.505
# Step 35, Avg. Returns: 55.535 +/- 40.988, Median: 52.357, Q-Network Loss: 0.461
# Step 36, Avg. Returns: 53.655 +/- 49.991, Median: 47.562, Q-Network Loss: 0.344
# Step 37, Avg. Returns: 52.651 +/- 36.260, Median: 53.205, Q-Network Loss: 1.975
# Step 131, Avg. Returns: 67.241 +/- 44.360, Median: 63.284, Q-Network Loss: 0.065
# Step 132, Avg. Returns: 58.025 +/- 41.355, Median: 60.972, Q-Network Loss: 0.330
# Step 133, Avg. Returns: 58.435 +/- 43.606, Median: 51.236, Q-Network Loss: 0.115
# Step 134, Avg. Returns: 41.463 +/- 24.747, Median: 46.847, Q-Network Loss: 0.032
# Step 135, Avg. Returns: 48.757 +/- 24.801, Median: 50.913, Q-Network Loss: 2.362
# Step 136, Avg. Returns: 55.225 +/- 42.225, Median: 61.241, Q-Network Loss: 0.087
# Step 137, Avg. Returns: 51.940 +/- 30.457, Median: 52.291, Q-Network Loss: 0.099
# Step 138, Avg. Returns: 17.475 +/- 21.668, Median: 4.681, Q-Network Loss: 0.056
# Step 139, Avg. Returns: 4.978 +/- 13.148, Median: 1.037, Q-Network Loss: 0.079
# Step 140, Avg. Returns: 1.054 +/- 3.550, Median: 1.255, Q-Network Loss: 0.084
# Step 141, Avg. Returns: 1.159 +/- 0.291, Median: 1.126, Q-Network Loss: 0.083
# Step 142, Avg. Returns: 1.231 +/- 0.378, Median: 1.172, Q-Network Loss: 0.073
# Step 143, Avg. Returns: 1.240 +/- 0.331, Median: 1.138, Q-Network Loss: 0.072
# Step 144, Avg. Returns: 1.391 +/- 0.349, Median: 1.353, Q-Network Loss: 0.059
# Step 145, Avg. Returns: 1.268 +/- 0.264, Median: 1.279, Q-Network Loss: 0.044
# Step 146, Avg. Returns: 1.205 +/- 0.368, Median: 1.221, Q-Network Loss: 0.041
# Step 147, Avg. Returns: 1.296 +/- 0.427, Median: 1.207, Q-Network Loss: 0.029
# Step 148, Avg. Returns: 1.291 +/- 0.323, Median: 1.218, Q-Network Loss: 0.025
# Step 149, Avg. Returns: 1.249 +/- 0.323, Median: 1.225, Q-Network Loss: 0.015
# Step 150, Avg. Returns: 0.258 +/- 0.797, Median: -0.039, Q-Network Loss: 0.009
# Step 151, Avg. Returns: -0.732 +/- 0.179, Median: -0.712, Q-Network Loss: 0.006
# Step 152, Avg. Returns: -0.718 +/- 0.155, Median: -0.729, Q-Network Loss: 0.003
# Step 153, Avg. Returns: -0.510 +/- 0.307, Median: -0.656, Q-Network Loss: 0.002
# Step 154, Avg. Returns: -0.521 +/- 0.341, Median: -0.577, Q-Network Loss: 0.001
# Step 155, Avg. Returns: -0.419 +/- 0.548, Median: -0.683, Q-Network Loss: 0.000
# Step 156, Avg. Returns: -0.569 +/- 0.683, Median: -0.773, Q-Network Loss: 0.000
# Step 157, Avg. Returns: -0.241 +/- 0.809, Median: -0.667, Q-Network Loss: 0.001
# Step 158, Avg. Returns: 0.698 +/- 0.665, Median: 0.456, Q-Network Loss: 0.003
# Step 159, Avg. Returns: -1.070 +/- 2.526, Median: 0.679, Q-Network Loss: 0.002
# Step 160, Avg. Returns: 0.176 +/- 1.958, Median: 0.896, Q-Network Loss: 0.002
# Step 161, Avg. Returns: 0.876 +/- 2.113, Median: 1.127, Q-Network Loss: 0.003
# Step 162, Avg. Returns: 0.933 +/- 2.237, Median: 1.033, Q-Network Loss: 0.003
# Step 163, Avg. Returns: -0.090 +/- 2.234, Median: 1.049, Q-Network Loss: 0.003
# Step 164, Avg. Returns: 0.581 +/- 1.747, Median: 1.099, Q-Network Loss: 0.003
# Step 165, Avg. Returns: 0.458 +/- 2.151, Median: 1.394, Q-Network Loss: 0.003
# Step 166, Avg. Returns: -0.579 +/- 2.546, Median: 1.093, Q-Network Loss: 1.582
# Step 167, Avg. Returns: 0.279 +/- 2.025, Median: 1.035, Q-Network Loss: 0.002
# Step 168, Avg. Returns: -0.069 +/- 2.283, Median: 0.998, Q-Network Loss: 0.003
# Step 169, Avg. Returns: -0.297 +/- 2.410, Median: 1.125, Q-Network Loss: 0.003
# Step 170, Avg. Returns: 0.824 +/- 1.238, Median: 1.143, Q-Network Loss: 0.004
# Step 171, Avg. Returns: 0.069 +/- 2.346, Median: 1.087, Q-Network Loss: 0.003
# Step 172, Avg. Returns: 0.226 +/- 2.024, Median: 1.000, Q-Network Loss: 0.003
# Step 173, Avg. Returns: -0.111 +/- 2.185, Median: 1.036, Q-Network Loss: 0.003
# Step 174, Avg. Returns: -0.231 +/- 2.195, Median: 0.835, Q-Network Loss: 0.003
# Step 175, Avg. Returns: -0.347 +/- 2.115, Median: 0.750, Q-Network Loss: 0.001
# Step 176, Avg. Returns: 0.063 +/- 1.912, Median: 0.874, Q-Network Loss: 0.001
# Step 177, Avg. Returns: 0.535 +/- 1.714, Median: 1.092, Q-Network Loss: 0.001
# Step 178, Avg. Returns: -0.477 +/- 2.365, Median: 0.827, Q-Network Loss: 0.002
# Step 179, Avg. Returns: 0.276 +/- 2.041, Median: 1.084, Q-Network Loss: 0.002
# Step 180, Avg. Returns: -0.968 +/- 2.648, Median: 0.791, Q-Network Loss: 0.001
# Step 181, Avg. Returns: 0.104 +/- 1.983, Median: 0.837, Q-Network Loss: 0.001
# Step 182, Avg. Returns: -0.596 +/- 2.294, Median: 0.838, Q-Network Loss: 0.001
# Step 183, Avg. Returns: 0.887 +/- 1.310, Median: 1.130, Q-Network Loss: 0.001
# Step 184, Avg. Returns: 0.375 +/- 2.053, Median: 1.184, Q-Network Loss: 0.001
# Step 185, Avg. Returns: 0.218 +/- 2.044, Median: 0.991, Q-Network Loss: 0.001
# Step 186, Avg. Returns: 0.450 +/- 1.640, Median: 0.954, Q-Network Loss: 0.001
# Step 187, Avg. Returns: -0.205 +/- 2.182, Median: 0.964, Q-Network Loss: 0.001
# Step 188, Avg. Returns: 0.405 +/- 2.151, Median: 1.313, Q-Network Loss: 0.001
# Step 189, Avg. Returns: 0.080 +/- 1.922, Median: 0.939, Q-Network Loss: 0.001
# Step 190, Avg. Returns: 0.113 +/- 1.956, Median: 0.922, Q-Network Loss: 0.001
# Step 191, Avg. Returns: 0.282 +/- 2.060, Median: 1.063, Q-Network Loss: 0.001
# Step 192, Avg. Returns: 0.251 +/- 1.986, Median: 0.913, Q-Network Loss: 0.001
# Step 193, Avg. Returns: -0.440 +/- 2.371, Median: 0.813, Q-Network Loss: 0.001
# Step 194, Avg. Returns: 0.535 +/- 1.726, Median: 1.138, Q-Network Loss: 0.000
# Step 195, Avg. Returns: 1.159 +/- 0.421, Median: 1.103, Q-Network Loss: 0.000
# Step 196, Avg. Returns: 0.450 +/- 1.685, Median: 1.071, Q-Network Loss: 0.001
# Step 197, Avg. Returns: -0.393 +/- 2.401, Median: 0.820, Q-Network Loss: 0.001
# Step 198, Avg. Returns: 0.819 +/- 1.233, Median: 1.163, Q-Network Loss: 0.001
# Step 199, Avg. Returns: 0.555 +/- 1.729, Median: 1.224, Q-Network Loss: 0.000
# Step 200, Avg. Returns: 0.445 +/- 1.646, Median: 0.927, Q-Network Loss: 0.000
# Step 201, Avg. Returns: 0.401 +/- 1.637, Median: 0.883, Q-Network Loss: 0.000
# Step 202, Avg. Returns: 0.703 +/- 1.257, Median: 1.032, Q-Network Loss: 0.000
# Step 203, Avg. Returns: 0.246 +/- 2.049, Median: 0.967, Q-Network Loss: 0.000
# Step 204, Avg. Returns: 0.168 +/- 2.498, Median: 1.137, Q-Network Loss: 0.000
# Step 205, Avg. Returns: -0.810 +/- 2.450, Median: 0.699, Q-Network Loss: 0.000
# Step 206, Avg. Returns: 0.427 +/- 1.691, Median: 0.957, Q-Network Loss: 0.000
# Step 207, Avg. Returns: 0.129 +/- 2.002, Median: 0.933, Q-Network Loss: 0.001
# Step 208, Avg. Returns: 0.198 +/- 1.942, Median: 1.066, Q-Network Loss: 0.000
# Step 209, Avg. Returns: 0.267 +/- 2.120, Median: 1.130, Q-Network Loss: 0.000
# Step 210, Avg. Returns: -0.397 +/- 2.400, Median: 0.787, Q-Network Loss: 0.000
# Step 211, Avg. Returns: 0.055 +/- 1.942, Median: 0.789, Q-Network Loss: 0.001
# Step 212, Avg. Returns: 0.837 +/- 0.219, Median: 0.813, Q-Network Loss: 0.000
# Step 213, Avg. Returns: 0.938 +/- 0.313, Median: 0.923, Q-Network Loss: 0.000
# Step 214, Avg. Returns: 0.936 +/- 0.476, Median: 0.831, Q-Network Loss: 0.000
# Step 215, Avg. Returns: 0.878 +/- 0.288, Median: 0.849, Q-Network Loss: 0.000
# Step 216, Avg. Returns: 0.910 +/- 0.538, Median: 0.726, Q-Network Loss: 0.000
# Step 217, Avg. Returns: 0.755 +/- 0.337, Median: 0.801, Q-Network Loss: 0.000
# Step 218, Avg. Returns: 0.746 +/- 0.403, Median: 0.737, Q-Network Loss: 0.001
# Step 219, Avg. Returns: 0.806 +/- 0.541, Median: 0.973, Q-Network Loss: 0.000
# Step 220, Avg. Returns: 0.785 +/- 0.727, Median: 1.031, Q-Network Loss: 0.000
# Step 221, Avg. Returns: 0.616 +/- 0.611, Median: 0.795, Q-Network Loss: 0.000
# Step 222, Avg. Returns: 0.712 +/- 0.455, Median: 0.680, Q-Network Loss: 0.001
# Step 223, Avg. Returns: 0.837 +/- 0.520, Median: 1.019, Q-Network Loss: 0.000
# Step 224, Avg. Returns: 0.716 +/- 0.655, Median: 0.807, Q-Network Loss: 0.000
# Step 225, Avg. Returns: 0.412 +/- 0.657, Median: 0.088, Q-Network Loss: 0.000
# Step 226, Avg. Returns: 0.215 +/- 0.882, Median: 0.120, Q-Network Loss: 0.000
# Step 227, Avg. Returns: 0.401 +/- 0.955, Median: 0.987, Q-Network Loss: 0.000
# Step 228, Avg. Returns: 0.556 +/- 0.824, Median: 0.950, Q-Network Loss: 0.000
# Step 229, Avg. Returns: 0.516 +/- 0.772, Median: 0.828, Q-Network Loss: 0.000
# Step 230, Avg. Returns: 0.259 +/- 0.780, Median: 0.722, Q-Network Loss: 0.000
# Step 231, Avg. Returns: 0.254 +/- 1.009, Median: 0.391, Q-Network Loss: 0.000
# Step 232, Avg. Returns: 0.284 +/- 0.887, Median: 0.747, Q-Network Loss: 0.000
# Step 233, Avg. Returns: 0.538 +/- 0.867, Median: 0.760, Q-Network Loss: 0.000
# Step 234, Avg. Returns: 0.077 +/- 0.938, Median: 0.369, Q-Network Loss: 0.000
# Step 235, Avg. Returns: 0.407 +/- 0.916, Median: 0.988, Q-Network Loss: 0.000
# Step 236, Avg. Returns: 0.236 +/- 0.965, Median: 0.728, Q-Network Loss: 0.000
# Step 237, Avg. Returns: 0.351 +/- 0.833, Median: 0.628, Q-Network Loss: 0.000
# Step 238, Avg. Returns: 0.499 +/- 0.898, Median: 0.885, Q-Network Loss: 0.001
# Step 239, Avg. Returns: 0.246 +/- 0.740, Median: 0.016, Q-Network Loss: 0.000
# Step 240, Avg. Returns: 0.461 +/- 0.630, Median: 0.765, Q-Network Loss: 0.000
# Step 241, Avg. Returns: 0.613 +/- 0.586, Median: 0.854, Q-Network Loss: 0.000
# Step 242, Avg. Returns: 0.486 +/- 0.841, Median: 0.461, Q-Network Loss: 0.000
# Step 243, Avg. Returns: 0.709 +/- 0.546, Median: 0.867, Q-Network Loss: 0.000
# Step 244, Avg. Returns: 0.598 +/- 0.529, Median: 0.694, Q-Network Loss: 0.000
# Step 245, Avg. Returns: 0.550 +/- 0.587, Median: 0.393, Q-Network Loss: 0.000
# Step 246, Avg. Returns: 0.851 +/- 0.469, Median: 0.818, Q-Network Loss: 0.000
# Step 247, Avg. Returns: 0.864 +/- 0.322, Median: 0.899, Q-Network Loss: 0.000
# Step 248, Avg. Returns: 0.987 +/- 0.400, Median: 0.939, Q-Network Loss: 0.000
# Step 249, Avg. Returns: 0.857 +/- 0.310, Median: 0.833, Q-Network Loss: 0.000
# Step 250, Avg. Returns: 0.896 +/- 0.304, Median: 0.916, Q-Network Loss: 0.000
# Step 251, Avg. Returns: 0.975 +/- 0.424, Median: 1.073, Q-Network Loss: 0.000
# Step 252, Avg. Returns: 1.086 +/- 0.445, Median: 1.122, Q-Network Loss: 0.000
# Step 253, Avg. Returns: 0.817 +/- 0.265, Median: 0.800, Q-Network Loss: 0.000
# Step 254, Avg. Returns: 0.885 +/- 0.545, Median: 0.856, Q-Network Loss: 0.000
# Step 255, Avg. Returns: 0.771 +/- 0.284, Median: 0.767, Q-Network Loss: 0.000
# Step 256, Avg. Returns: 0.883 +/- 0.344, Median: 0.860, Q-Network Loss: 0.000
# Step 257, Avg. Returns: 0.906 +/- 0.780, Median: 0.678, Q-Network Loss: 0.000
# Step 258, Avg. Returns: 0.882 +/- 0.463, Median: 0.932, Q-Network Loss: 0.000
# Step 259, Avg. Returns: 0.898 +/- 0.335, Median: 0.920, Q-Network Loss: 0.000
# Step 260, Avg. Returns: 0.949 +/- 0.331, Median: 0.866, Q-Network Loss: 0.000
# Step 261, Avg. Returns: 0.947 +/- 0.665, Median: 0.800, Q-Network Loss: 0.000
# Step 262, Avg. Returns: 0.783 +/- 0.352, Median: 0.725, Q-Network Loss: 0.000
# Step 263, Avg. Returns: 1.564 +/- 2.291, Median: 0.741, Q-Network Loss: 0.000
# Step 264, Avg. Returns: 0.962 +/- 0.542, Median: 0.836, Q-Network Loss: 0.000
# Step 265, Avg. Returns: 2.594 +/- 3.586, Median: 0.873, Q-Network Loss: 0.000
# Step 266, Avg. Returns: 0.809 +/- 0.199, Median: 0.814, Q-Network Loss: 0.000
# Step 267, Avg. Returns: 1.359 +/- 2.276, Median: 0.754, Q-Network Loss: 0.000
# Step 268, Avg. Returns: 1.469 +/- 3.170, Median: 0.934, Q-Network Loss: 0.000
# Step 269, Avg. Returns: 1.192 +/- 1.383, Median: 0.780, Q-Network Loss: 0.000
# Step 270, Avg. Returns: 1.407 +/- 2.308, Median: 0.741, Q-Network Loss: 0.002
# Step 271, Avg. Returns: 0.916 +/- 2.386, Median: 0.679, Q-Network Loss: 0.000
# Step 272, Avg. Returns: 1.158 +/- 1.584, Median: 0.765, Q-Network Loss: 0.000
# Step 273, Avg. Returns: 0.705 +/- 0.269, Median: 0.644, Q-Network Loss: 0.000
# Step 274, Avg. Returns: 1.720 +/- 4.196, Median: 0.505, Q-Network Loss: 0.000
# Step 275, Avg. Returns: 1.329 +/- 2.280, Median: 0.666, Q-Network Loss: 0.047
# Step 276, Avg. Returns: 0.176 +/- 0.312, Median: 0.061, Q-Network Loss: 0.000
# Step 277, Avg. Returns: 0.225 +/- 0.571, Median: 0.054, Q-Network Loss: 0.000
# Step 278, Avg. Returns: 0.265 +/- 0.918, Median: 0.652, Q-Network Loss: 0.000
# Step 279, Avg. Returns: -0.287 +/- 0.907, Median: -0.750, Q-Network Loss: 0.000
# Step 280, Avg. Returns: -0.532 +/- 0.664, Median: -0.829, Q-Network Loss: 0.000
# Step 281, Avg. Returns: 1.466 +/- 5.596, Median: 0.779, Q-Network Loss: 0.000
# Step 282, Avg. Returns: -0.480 +/- 0.866, Median: -0.868, Q-Network Loss: 0.000
# Step 283, Avg. Returns: 11.821 +/- 21.638, Median: 0.975, Q-Network Loss: 0.000
# Step 284, Avg. Returns: 20.570 +/- 31.697, Median: 1.755, Q-Network Loss: 0.002
# Step 285, Avg. Returns: 27.946 +/- 44.061, Median: 1.126, Q-Network Loss: 0.014
# Step 286, Avg. Returns: 73.077 +/- 51.622, Median: 57.174, Q-Network Loss: 0.130
# Step 287, Avg. Returns: 65.776 +/- 29.265, Median: 60.982, Q-Network Loss: 0.500
# Step 288, Avg. Returns: 76.176 +/- 37.792, Median: 60.501, Q-Network Loss: 0.097
# Step 289, Avg. Returns: 77.452 +/- 52.967, Median: 69.898, Q-Network Loss: 0.814
# Step 290, Avg. Returns: 51.824 +/- 49.787, Median: 35.449, Q-Network Loss: 0.321
# Step 291, Avg. Returns: 80.288 +/- 53.511, Median: 81.650, Q-Network Loss: 0.369
# Step 292, Avg. Returns: 75.256 +/- 50.652, Median: 60.278, Q-Network Loss: 0.742
# Step 293, Avg. Returns: 60.264 +/- 42.443, Median: 56.836, Q-Network Loss: 0.345
# Step 294, Avg. Returns: 51.625 +/- 24.285, Median: 53.123, Q-Network Loss: 0.041
# Step 295, Avg. Returns: 73.994 +/- 50.998, Median: 55.720, Q-Network Loss: 0.181
# Step 296, Avg. Returns: 73.758 +/- 60.378, Median: 65.874, Q-Network Loss: 0.185
# Step 297, Avg. Returns: 82.660 +/- 45.705, Median: 73.185, Q-Network Loss: 0.216
# Step 298, Avg. Returns: 73.743 +/- 48.789, Median: 65.628, Q-Network Loss: 0.144
# Step 299, Avg. Returns: 70.120 +/- 49.758, Median: 66.087, Q-Network Loss: 0.198
# Step 300, Avg. Returns: 59.014 +/- 34.020, Median: 59.270, Q-Network Loss: 0.199
# Step 301, Avg. Returns: 65.783 +/- 40.059, Median: 61.735, Q-Network Loss: 3.400
# Step 302, Avg. Returns: 74.776 +/- 46.902, Median: 65.471, Q-Network Loss: 0.192
# Step 303, Avg. Returns: 70.506 +/- 34.761, Median: 67.096, Q-Network Loss: 1.984
# Step 304, Avg. Returns: 77.214 +/- 59.881, Median: 57.636, Q-Network Loss: 0.045
# Step 305, Avg. Returns: 59.182 +/- 23.859, Median: 58.189, Q-Network Loss: 0.106
# Step 306, Avg. Returns: 58.901 +/- 30.870, Median: 56.551, Q-Network Loss: 0.149
# Step 307, Avg. Returns: 67.070 +/- 20.514, Median: 60.069, Q-Network Loss: 2.405
# Step 308, Avg. Returns: 55.798 +/- 44.095, Median: 53.327, Q-Network Loss: 0.096
# Step 309, Avg. Returns: 79.490 +/- 54.845, Median: 57.912, Q-Network Loss: 0.138
# Step 310, Avg. Returns: 55.230 +/- 48.131, Median: 43.748, Q-Network Loss: 2.765
# Step 311, Avg. Returns: 73.686 +/- 38.786, Median: 65.746, Q-Network Loss: 0.223
# Step 312, Avg. Returns: 73.590 +/- 27.274, Median: 69.810, Q-Network Loss: 0.250
# Step 313, Avg. Returns: 72.950 +/- 46.347, Median: 59.637, Q-Network Loss: 0.267
# Step 314, Avg. Returns: 47.817 +/- 22.356, Median: 53.515, Q-Network Loss: 0.178
# Step 315, Avg. Returns: 70.949 +/- 68.576, Median: 59.687, Q-Network Loss: 0.285
# Step 316, Avg. Returns: 76.099 +/- 39.889, Median: 63.830, Q-Network Loss: 0.168
# Step 317, Avg. Returns: 69.950 +/- 43.461, Median: 60.362, Q-Network Loss: 0.106
# Step 318, Avg. Returns: 60.447 +/- 52.412, Median: 50.566, Q-Network Loss: 0.143
# Step 319, Avg. Returns: 47.721 +/- 31.962, Median: 52.224, Q-Network Loss: 0.128
# Step 320, Avg. Returns: 67.886 +/- 58.299, Median: 61.167, Q-Network Loss: 0.086
# Step 321, Avg. Returns: 70.180 +/- 45.936, Median: 60.124, Q-Network Loss: 1.937
# Step 322, Avg. Returns: 84.061 +/- 41.468, Median: 63.619, Q-Network Loss: 0.086
# Step 323, Avg. Returns: 72.385 +/- 41.730, Median: 64.639, Q-Network Loss: 0.075
# Step 324, Avg. Returns: 63.816 +/- 31.917, Median: 61.235, Q-Network Loss: 0.075
# Step 325, Avg. Returns: 60.040 +/- 44.258, Median: 47.792, Q-Network Loss: 0.148
# Step 326, Avg. Returns: 82.717 +/- 31.589, Median: 66.028, Q-Network Loss: 3.016
# Step 327, Avg. Returns: 67.038 +/- 46.508, Median: 54.526, Q-Network Loss: 0.070
# Step 328, Avg. Returns: 66.612 +/- 37.645, Median: 60.108, Q-Network Loss: 0.375
# Step 329, Avg. Returns: 62.307 +/- 30.243, Median: 59.501, Q-Network Loss: 0.116
# Step 330, Avg. Returns: 77.354 +/- 43.890, Median: 61.816, Q-Network Loss: 0.098
# Step 331, Avg. Returns: 81.798 +/- 46.056, Median: 58.434, Q-Network Loss: 0.105
# Step 332, Avg. Returns: 67.746 +/- 41.071, Median: 58.812, Q-Network Loss: 0.122
# Step 333, Avg. Returns: 85.369 +/- 45.556, Median: 67.804, Q-Network Loss: 0.144
# Step 334, Avg. Returns: 75.281 +/- 55.413, Median: 58.364, Q-Network Loss: 0.167
# Step 335, Avg. Returns: 63.135 +/- 29.630, Median: 57.919, Q-Network Loss: 3.345
# Step 336, Avg. Returns: 57.310 +/- 34.413, Median: 54.752, Q-Network Loss: 0.055
# Step 337, Avg. Returns: 80.902 +/- 42.012, Median: 84.963, Q-Network Loss: 0.155
# Step 338, Avg. Returns: 62.035 +/- 30.780, Median: 58.480, Q-Network Loss: 0.094
# Step 339, Avg. Returns: 61.453 +/- 33.275, Median: 58.139, Q-Network Loss: 0.056
# Step 340, Avg. Returns: 76.147 +/- 49.756, Median: 60.442, Q-Network Loss: 0.113
# Step 341, Avg. Returns: 77.150 +/- 50.385, Median: 64.938, Q-Network Loss: 0.133
# Step 342, Avg. Returns: 86.603 +/- 56.811, Median: 60.589, Q-Network Loss: 0.065
# Step 343, Avg. Returns: 69.062 +/- 34.355, Median: 58.449, Q-Network Loss: 0.276
# Step 344, Avg. Returns: 50.858 +/- 33.780, Median: 50.702, Q-Network Loss: 0.117
# Step 345, Avg. Returns: 58.976 +/- 38.316, Median: 52.228, Q-Network Loss: 0.134
# Step 346, Avg. Returns: 23.548 +/- 45.853, Median: -0.817, Q-Network Loss: 0.079
# Step 347, Avg. Returns: -0.778 +/- 0.392, Median: -0.816, Q-Network Loss: 0.131
# Step 348, Avg. Returns: -0.439 +/- 0.720, Median: -0.768, Q-Network Loss: 0.145
# Step 349, Avg. Returns: 0.718 +/- 0.459, Median: 0.776, Q-Network Loss: 0.147
# Step 350, Avg. Returns: 2.127 +/- 3.794, Median: 0.705, Q-Network Loss: 0.129
# Step 351, Avg. Returns: 2.428 +/- 4.528, Median: 0.765, Q-Network Loss: 0.109
# Step 352, Avg. Returns: 0.857 +/- 0.274, Median: 0.916, Q-Network Loss: 0.083
# Step 353, Avg. Returns: 1.046 +/- 0.501, Median: 0.917, Q-Network Loss: 0.065
# Step 354, Avg. Returns: 9.110 +/- 16.884, Median: 0.913, Q-Network Loss: 0.039
# Step 355, Avg. Returns: 30.061 +/- 27.191, Median: 30.720, Q-Network Loss: 0.032
# Step 356, Avg. Returns: 61.286 +/- 38.532, Median: 63.007, Q-Network Loss: 0.070
# Step 357, Avg. Returns: 33.532 +/- 41.179, Median: 2.197, Q-Network Loss: 0.117
# Step 358, Avg. Returns: 52.622 +/- 53.126, Median: 49.094, Q-Network Loss: 0.112
# Step 359, Avg. Returns: 53.222 +/- 44.788, Median: 59.246, Q-Network Loss: 0.057
# Step 360, Avg. Returns: 68.088 +/- 76.871, Median: 58.695, Q-Network Loss: 0.107
# Step 361, Avg. Returns: 52.875 +/- 35.829, Median: 61.072, Q-Network Loss: 0.202
# Step 362, Avg. Returns: 82.941 +/- 50.882, Median: 84.488, Q-Network Loss: 0.160
# Step 363, Avg. Returns: 53.923 +/- 48.788, Median: 39.110, Q-Network Loss: 3.125
# Step 364, Avg. Returns: 62.607 +/- 36.791, Median: 58.994, Q-Network Loss: 1.732
# Step 365, Avg. Returns: 66.340 +/- 28.725, Median: 61.271, Q-Network Loss: 0.063
# Step 366, Avg. Returns: 66.150 +/- 42.095, Median: 58.967, Q-Network Loss: 2.227
# Step 367, Avg. Returns: 63.368 +/- 42.861, Median: 53.786, Q-Network Loss: 0.195
# Step 368, Avg. Returns: 82.841 +/- 44.880, Median: 86.264, Q-Network Loss: 0.100
# Step 369, Avg. Returns: 83.804 +/- 45.186, Median: 66.554, Q-Network Loss: 0.069
# Step 370, Avg. Returns: 76.238 +/- 49.987, Median: 58.321, Q-Network Loss: 3.273
# Step 371, Avg. Returns: 57.778 +/- 36.232, Median: 55.517, Q-Network Loss: 0.203
# Step 372, Avg. Returns: 78.399 +/- 52.407, Median: 65.175, Q-Network Loss: 0.083
# Step 373, Avg. Returns: 55.509 +/- 32.378, Median: 56.174, Q-Network Loss: 3.260
# Step 374, Avg. Returns: 68.471 +/- 49.780, Median: 61.076, Q-Network Loss: 0.074
# Step 375, Avg. Returns: 59.265 +/- 28.068, Median: 59.668, Q-Network Loss: 0.070
# Step 376, Avg. Returns: 54.514 +/- 34.998, Median: 54.810, Q-Network Loss: 0.046
# Step 377, Avg. Returns: 55.849 +/- 28.737, Median: 56.705, Q-Network Loss: 1.765
# Step 378, Avg. Returns: 81.479 +/- 35.761, Median: 72.371, Q-Network Loss: 0.063
# Step 379, Avg. Returns: 58.728 +/- 34.943, Median: 58.781, Q-Network Loss: 0.066
# Step 380, Avg. Returns: 82.172 +/- 36.579, Median: 72.813, Q-Network Loss: 0.057
# Step 381, Avg. Returns: 71.083 +/- 34.411, Median: 60.098, Q-Network Loss: 0.038
# Step 382, Avg. Returns: 70.911 +/- 40.296, Median: 61.217, Q-Network Loss: 0.059
# Step 383, Avg. Returns: 72.675 +/- 48.059, Median: 65.428, Q-Network Loss: 0.079
# Step 384, Avg. Returns: 52.484 +/- 28.029, Median: 56.702, Q-Network Loss: 0.072
# Step 385, Avg. Returns: 71.422 +/- 36.073, Median: 63.190, Q-Network Loss: 0.052
# Step 386, Avg. Returns: 79.297 +/- 52.863, Median: 61.213, Q-Network Loss: 0.035
# Step 387, Avg. Returns: 67.216 +/- 35.765, Median: 60.239, Q-Network Loss: 0.053
# Step 388, Avg. Returns: 66.699 +/- 48.720, Median: 53.962, Q-Network Loss: 0.137
# Step 389, Avg. Returns: 79.852 +/- 41.476, Median: 66.991, Q-Network Loss: 3.472
# Step 390, Avg. Returns: 59.731 +/- 35.853, Median: 54.578, Q-Network Loss: 3.475
# Step 391, Avg. Returns: 75.369 +/- 47.000, Median: 64.547, Q-Network Loss: 0.093
# Step 392, Avg. Returns: 64.032 +/- 33.205, Median: 57.484, Q-Network Loss: 0.109
# Step 393, Avg. Returns: 72.782 +/- 43.554, Median: 56.135, Q-Network Loss: 0.281
# Step 394, Avg. Returns: 53.070 +/- 30.625, Median: 54.685, Q-Network Loss: 0.055
# Step 395, Avg. Returns: 85.528 +/- 46.371, Median: 81.388, Q-Network Loss: 0.212
# Step 396, Avg. Returns: 87.319 +/- 44.567, Median: 68.181, Q-Network Loss: 0.198
# Step 397, Avg. Returns: 44.435 +/- 38.290, Median: 29.644, Q-Network Loss: 2.856
# Step 398, Avg. Returns: 67.973 +/- 44.966, Median: 64.278, Q-Network Loss: 0.153
# Step 399, Avg. Returns: 44.217 +/- 22.155, Median: 52.025, Q-Network Loss: 0.176
# Step 400, Avg. Returns: 64.084 +/- 21.292, Median: 61.905, Q-Network Loss: 0.139
# Step 401, Avg. Returns: 60.815 +/- 36.505, Median: 53.797, Q-Network Loss: 1.797
# Step 402, Avg. Returns: 68.257 +/- 46.261, Median: 54.432, Q-Network Loss: 0.025
# Step 403, Avg. Returns: 68.061 +/- 34.759, Median: 64.443, Q-Network Loss: 3.649
# Step 404, Avg. Returns: 64.518 +/- 43.146, Median: 63.369, Q-Network Loss: 0.035
# Step 405, Avg. Returns: 48.670 +/- 24.388, Median: 54.627, Q-Network Loss: 0.079
# Step 406, Avg. Returns: 48.023 +/- 42.760, Median: 51.764, Q-Network Loss: 0.048
# Step 407, Avg. Returns: 25.533 +/- 34.646, Median: 0.668, Q-Network Loss: 0.069
# Step 408, Avg. Returns: 12.609 +/- 33.081, Median: 0.768, Q-Network Loss: 0.061
# Step 440, Avg. Returns: 67.824 +/- 42.035, Median: 57.658, Q-Network Loss: 0.066
# Step 441, Avg. Returns: 60.676 +/- 32.011, Median: 60.430, Q-Network Loss: 0.057
# Step 442, Avg. Returns: 55.098 +/- 32.584, Median: 52.674, Q-Network Loss: 0.131
# Step 443, Avg. Returns: 77.064 +/- 45.604, Median: 65.911, Q-Network Loss: 0.014
# Step 444, Avg. Returns: 69.397 +/- 62.056, Median: 53.347, Q-Network Loss: 0.083
# Step 445, Avg. Returns: 78.142 +/- 48.637, Median: 61.346, Q-Network Loss: 0.153
# Step 446, Avg. Returns: 84.519 +/- 65.758, Median: 62.440, Q-Network Loss: 0.209
# Step 447, Avg. Returns: 76.495 +/- 38.192, Median: 62.844, Q-Network Loss: 0.036
# Step 448, Avg. Returns: 67.803 +/- 42.992, Median: 65.035, Q-Network Loss: 0.055
# Step 449, Avg. Returns: 72.982 +/- 38.021, Median: 66.315, Q-Network Loss: 0.093
# Step 450, Avg. Returns: 63.827 +/- 26.379, Median: 61.975, Q-Network Loss: 0.056
# Step 451, Avg. Returns: 70.670 +/- 41.163, Median: 59.994, Q-Network Loss: 2.064
# Step 452, Avg. Returns: 57.463 +/- 28.709, Median: 58.582, Q-Network Loss: 0.110
# Step 453, Avg. Returns: 89.757 +/- 38.804, Median: 88.390, Q-Network Loss: 0.045
# Step 454, Avg. Returns: 65.100 +/- 36.281, Median: 54.035, Q-Network Loss: 0.056
# Step 455, Avg. Returns: 78.148 +/- 40.645, Median: 61.607, Q-Network Loss: 0.094
# Step 456, Avg. Returns: 74.367 +/- 34.038, Median: 59.566, Q-Network Loss: 0.030
# Step 457, Avg. Returns: 55.729 +/- 56.618, Median: 54.932, Q-Network Loss: 0.051
# Step 458, Avg. Returns: 74.052 +/- 53.174, Median: 63.788, Q-Network Loss: 0.046
# Step 459, Avg. Returns: 58.604 +/- 44.298, Median: 52.914, Q-Network Loss: 3.487
# Step 460, Avg. Returns: 23.269 +/- 50.960, Median: 0.632, Q-Network Loss: 0.044
# Step 461, Avg. Returns: 0.343 +/- 0.678, Median: 0.494, Q-Network Loss: 0.038
# Step 462, Avg. Returns: 0.780 +/- 0.359, Median: 0.676, Q-Network Loss: 0.036
# Step 463, Avg. Returns: 0.742 +/- 0.291, Median: 0.667, Q-Network Loss: 0.038
# Step 464, Avg. Returns: 0.719 +/- 0.278, Median: 0.687, Q-Network Loss: 0.020
# Step 465, Avg. Returns: 0.631 +/- 0.436, Median: 0.836, Q-Network Loss: 0.008
# Step 466, Avg. Returns: 0.453 +/- 0.279, Median: 0.441, Q-Network Loss: 0.003
# Step 467, Avg. Returns: -0.222 +/- 0.841, Median: -0.611, Q-Network Loss: 0.001
# Step 468, Avg. Returns: -0.643 +/- 0.660, Median: -1.008, Q-Network Loss: 0.000
# Step 469, Avg. Returns: -0.764 +/- 0.695, Median: -1.081, Q-Network Loss: 0.002
# Step 470, Avg. Returns: -0.450 +/- 0.754, Median: -0.901, Q-Network Loss: 0.006
# Step 471, Avg. Returns: -0.409 +/- 0.888, Median: -0.983, Q-Network Loss: 0.005
# Step 472, Avg. Returns: -0.752 +/- 0.758, Median: -1.041, Q-Network Loss: 0.007
# Step 473, Avg. Returns: -0.105 +/- 0.976, Median: 0.257, Q-Network Loss: 0.006
# Step 474, Avg. Returns: -0.385 +/- 0.930, Median: -0.954, Q-Network Loss: 0.008
# Step 475, Avg. Returns: -0.649 +/- 0.875, Median: -1.029, Q-Network Loss: 0.006
# Step 476, Avg. Returns: -0.772 +/- 0.756, Median: -1.075, Q-Network Loss: 0.008
# Step 477, Avg. Returns: -0.456 +/- 0.867, Median: -0.989, Q-Network Loss: 0.006
# Step 478, Avg. Returns: -0.598 +/- 0.852, Median: -1.040, Q-Network Loss: 0.004
# Step 479, Avg. Returns: -1.032 +/- 1.410, Median: -1.109, Q-Network Loss: 0.009
# Step 480, Avg. Returns: -0.296 +/- 0.913, Median: -0.858, Q-Network Loss: 0.003
# Step 481, Avg. Returns: -0.542 +/- 1.305, Median: -1.082, Q-Network Loss: 0.001
# Step 482, Avg. Returns: -0.737 +/- 1.229, Median: -1.210, Q-Network Loss: 0.006
# Step 483, Avg. Returns: -0.927 +/- 1.084, Median: -1.071, Q-Network Loss: 0.002
# Step 484, Avg. Returns: -0.601 +/- 0.835, Median: -1.044, Q-Network Loss: 0.003
# Step 485, Avg. Returns: -1.327 +/- 1.463, Median: -1.130, Q-Network Loss: 0.002
# Step 486, Avg. Returns: -1.084 +/- 1.353, Median: -1.097, Q-Network Loss: 0.006
# Step 487, Avg. Returns: -1.132 +/- 0.966, Median: -1.125, Q-Network Loss: 0.002
# Step 488, Avg. Returns: -0.321 +/- 0.911, Median: -0.558, Q-Network Loss: 0.000
# Step 489, Avg. Returns: -0.726 +/- 0.711, Median: -1.024, Q-Network Loss: 0.001
# Step 490, Avg. Returns: -0.715 +/- 1.217, Median: -1.042, Q-Network Loss: 0.002
# Step 491, Avg. Returns: -0.625 +/- 1.193, Median: -0.773, Q-Network Loss: 0.002
# Step 492, Avg. Returns: -0.480 +/- 0.828, Median: -0.971, Q-Network Loss: 0.002
# Step 493, Avg. Returns: -1.040 +/- 0.938, Median: -1.070, Q-Network Loss: 0.001
# Step 494, Avg. Returns: -0.409 +/- 0.838, Median: -0.973, Q-Network Loss: 0.002
# Step 495, Avg. Returns: -0.507 +/- 0.859, Median: -0.966, Q-Network Loss: 0.004
# Step 496, Avg. Returns: -0.370 +/- 0.831, Median: -0.932, Q-Network Loss: 0.001
# Step 497, Avg. Returns: -0.961 +/- 1.039, Median: -1.084, Q-Network Loss: 0.002
# Step 498, Avg. Returns: -0.670 +/- 0.749, Median: -1.003, Q-Network Loss: 0.005
# Step 499, Avg. Returns: -0.904 +/- 0.537, Median: -1.030, Q-Network Loss: 0.003
# Step 500, Avg. Returns: -1.070 +/- 1.054, Median: -1.218, Q-Network Loss: 0.004
# Step 501, Avg. Returns: -0.874 +/- 0.698, Median: -1.200, Q-Network Loss: 0.002
# Step 502, Avg. Returns: -0.482 +/- 1.260, Median: -0.899, Q-Network Loss: 0.005
# Step 503, Avg. Returns: -0.115 +/- 0.931, Median: 0.395, Q-Network Loss: 0.003
# Step 504, Avg. Returns: -0.314 +/- 1.260, Median: 0.424, Q-Network Loss: 0.000
# Step 505, Avg. Returns: -0.087 +/- 0.901, Median: 0.464, Q-Network Loss: 0.004
# Step 506, Avg. Returns: -0.404 +/- 0.904, Median: -1.049, Q-Network Loss: 0.000
# Step 507, Avg. Returns: -0.998 +/- 0.515, Median: -1.170, Q-Network Loss: 0.000
# Step 508, Avg. Returns: -1.198 +/- 0.948, Median: -1.196, Q-Network Loss: 0.003
# Step 509, Avg. Returns: -0.954 +/- 0.686, Median: -1.172, Q-Network Loss: 0.000
# Step 510, Avg. Returns: -0.548 +/- 0.843, Median: -1.023, Q-Network Loss: 0.000
# Step 511, Avg. Returns: -0.418 +/- 0.865, Median: -0.952, Q-Network Loss: 0.001
# Step 512, Avg. Returns: -0.569 +/- 0.832, Median: -1.058, Q-Network Loss: 0.001
# Step 513, Avg. Returns: -0.478 +/- 0.837, Median: -0.978, Q-Network Loss: 0.000
# Step 514, Avg. Returns: -0.598 +/- 0.919, Median: -1.154, Q-Network Loss: 0.001
# Step 515, Avg. Returns: -0.678 +/- 0.797, Median: -1.067, Q-Network Loss: 0.000
# Step 516, Avg. Returns: -1.165 +/- 0.973, Median: -1.215, Q-Network Loss: 0.000
# Step 517, Avg. Returns: -1.409 +/- 1.105, Median: -1.206, Q-Network Loss: 0.000
# Step 518, Avg. Returns: -0.940 +/- 1.109, Median: -1.179, Q-Network Loss: 0.003
# Step 519, Avg. Returns: -0.829 +/- 0.738, Median: -1.227, Q-Network Loss: 0.002
# Step 520, Avg. Returns: -0.482 +/- 0.892, Median: -1.147, Q-Network Loss: 0.000
# Step 521, Avg. Returns: -1.122 +/- 1.260, Median: -1.006, Q-Network Loss: 0.001
# Step 522, Avg. Returns: -0.525 +/- 0.845, Median: -1.056, Q-Network Loss: 0.001
# Step 523, Avg. Returns: -0.816 +/- 0.658, Median: -1.079, Q-Network Loss: 0.003
# Step 524, Avg. Returns: -0.507 +/- 1.205, Median: -0.418, Q-Network Loss: 0.002
# Step 525, Avg. Returns: -0.769 +/- 1.194, Median: -1.102, Q-Network Loss: 0.000
# Step 526, Avg. Returns: -0.891 +/- 1.423, Median: -1.138, Q-Network Loss: 0.000
# Step 527, Avg. Returns: -0.871 +/- 1.119, Median: -1.097, Q-Network Loss: 0.001
# Step 528, Avg. Returns: -1.006 +/- 1.652, Median: -1.069, Q-Network Loss: 0.004
# Step 529, Avg. Returns: -0.484 +/- 0.953, Median: -1.128, Q-Network Loss: 0.000
# Step 530, Avg. Returns: -0.927 +/- 0.525, Median: -1.067, Q-Network Loss: 0.000
# Step 531, Avg. Returns: -1.189 +/- 1.297, Median: -1.191, Q-Network Loss: 0.001
# Step 532, Avg. Returns: -1.189 +/- 1.360, Median: -1.250, Q-Network Loss: 0.003
# Step 533, Avg. Returns: -0.495 +/- 0.869, Median: -1.138, Q-Network Loss: 0.000
# Step 534, Avg. Returns: -0.795 +/- 1.191, Median: -1.012, Q-Network Loss: 0.000
# Step 535, Avg. Returns: -0.533 +/- 0.782, Median: -0.980, Q-Network Loss: 0.000
# Step 536, Avg. Returns: -0.822 +/- 0.768, Median: -1.192, Q-Network Loss: 0.000
# Step 537, Avg. Returns: -1.241 +/- 1.526, Median: -1.138, Q-Network Loss: 0.000
# Step 538, Avg. Returns: -0.243 +/- 0.927, Median: -0.200, Q-Network Loss: 0.000
# Step 539, Avg. Returns: -0.353 +/- 0.882, Median: -0.358, Q-Network Loss: 0.000
# Step 540, Avg. Returns: -1.024 +/- 1.446, Median: -1.178, Q-Network Loss: 0.007
# Step 541, Avg. Returns: -0.296 +/- 0.865, Median: -0.308, Q-Network Loss: 0.001
# Step 542, Avg. Returns: -0.335 +/- 0.912, Median: -0.830, Q-Network Loss: 0.002
# Step 543, Avg. Returns: -0.465 +/- 0.843, Median: -0.956, Q-Network Loss: 0.004
# Step 544, Avg. Returns: -0.161 +/- 0.763, Median: 0.364, Q-Network Loss: 0.000
# Step 545, Avg. Returns: -0.775 +/- 0.537, Median: -1.017, Q-Network Loss: 0.000
# Step 546, Avg. Returns: -0.878 +/- 0.459, Median: -0.945, Q-Network Loss: 0.001
# Step 547, Avg. Returns: -0.833 +/- 0.493, Median: -1.029, Q-Network Loss: 0.002
# Step 548, Avg. Returns: -0.894 +/- 0.466, Median: -1.016, Q-Network Loss: 0.000
# Step 549, Avg. Returns: -0.639 +/- 0.538, Median: -0.822, Q-Network Loss: 0.000
# Step 550, Avg. Returns: -0.872 +/- 0.572, Median: -1.100, Q-Network Loss: 0.000
# Step 551, Avg. Returns: -0.820 +/- 0.518, Median: -1.031, Q-Network Loss: 0.000
# Step 552, Avg. Returns: -0.717 +/- 0.665, Median: -1.116, Q-Network Loss: 0.000
# Step 553, Avg. Returns: -0.411 +/- 0.771, Median: -0.041, Q-Network Loss: 0.002
# Step 554, Avg. Returns: -0.484 +/- 0.817, Median: -0.890, Q-Network Loss: 0.000
# Step 555, Avg. Returns: 0.187 +/- 0.695, Median: 0.526, Q-Network Loss: 0.000
# Step 556, Avg. Returns: -0.312 +/- 0.811, Median: 0.234, Q-Network Loss: 0.000
# Step 557, Avg. Returns: 0.143 +/- 0.727, Median: 0.414, Q-Network Loss: 0.000
# Step 558, Avg. Returns: -0.118 +/- 0.829, Median: 0.358, Q-Network Loss: 0.000
# Step 559, Avg. Returns: -0.057 +/- 0.932, Median: 0.490, Q-Network Loss: 0.001
# Step 560, Avg. Returns: -0.388 +/- 0.833, Median: -0.385, Q-Network Loss: 0.001
# Step 561, Avg. Returns: -0.960 +/- 0.630, Median: -1.244, Q-Network Loss: 0.000
# Step 562, Avg. Returns: -0.863 +/- 0.544, Median: -1.124, Q-Network Loss: 0.000
# Step 563, Avg. Returns: -0.918 +/- 0.537, Median: -1.194, Q-Network Loss: 0.000
# Step 595, Avg. Returns: -0.013 +/- 0.865, Median: 0.362, Q-Network Loss: 0.000
# Step 596, Avg. Returns: -0.077 +/- 0.901, Median: 0.348, Q-Network Loss: 0.000
# Step 597, Avg. Returns: -0.397 +/- 0.928, Median: -0.491, Q-Network Loss: 0.000
# ...
# Step 801, Avg. Returns: 91.527 +/- 41.385, Median: 68.211, Q-Network Loss: 0.106
# Step 802, Avg. Returns: 64.341 +/- 43.138, Median: 59.253, Q-Network Loss: 0.113
# Step 803, Avg. Returns: 65.878 +/- 25.832, Median: 67.315, Q-Network Loss: 0.237
# Step 804, Avg. Returns: 69.311 +/- 26.996, Median: 63.298, Q-Network Loss: 0.178
# Step 805, Avg. Returns: 84.797 +/- 44.937, Median: 71.004, Q-Network Loss: 0.209
# Step 806, Avg. Returns: 72.429 +/- 33.334, Median: 60.309, Q-Network Loss: 0.082
# Step 807, Avg. Returns: 79.119 +/- 48.309, Median: 63.351, Q-Network Loss: 0.130
# Step 808, Avg. Returns: 70.986 +/- 50.153, Median: 51.887, Q-Network Loss: 0.071
# Step 809, Avg. Returns: 70.928 +/- 31.473, Median: 60.534, Q-Network Loss: 7.214
# Step 810, Avg. Returns: 63.900 +/- 53.726, Median: 64.110, Q-Network Loss: 0.055
# Step 811, Avg. Returns: 69.275 +/- 62.604, Median: 64.966, Q-Network Loss: 1.864
# Step 812, Avg. Returns: 11.906 +/- 28.500, Median: -1.103, Q-Network Loss: 0.020
# Step 813, Avg. Returns: 15.507 +/- 35.369, Median: -1.181, Q-Network Loss: 0.136
# Step 814, Avg. Returns: -0.425 +/- 1.327, Median: -1.176, Q-Network Loss: 0.075
# Step 815, Avg. Returns: -0.721 +/- 1.041, Median: -1.304, Q-Network Loss: 0.004
# Step 816, Avg. Returns: -0.798 +/- 0.840, Median: -1.286, Q-Network Loss: 0.002
# Step 817, Avg. Returns: -1.032 +/- 0.672, Median: -1.331, Q-Network Loss: 0.002
# Step 818, Avg. Returns: -0.897 +/- 0.754, Median: -1.353, Q-Network Loss: 0.004
# Step 819, Avg. Returns: -1.104 +/- 0.387, Median: -1.250, Q-Network Loss: 0.004
# Step 820, Avg. Returns: -1.196 +/- 0.283, Median: -1.257, Q-Network Loss: 0.004
# Step 821, Avg. Returns: -1.246 +/- 0.205, Median: -1.212, Q-Network Loss: 0.006
# Step 822, Avg. Returns: -1.352 +/- 0.141, Median: -1.402, Q-Network Loss: 0.005
# Step 823, Avg. Returns: -1.370 +/- 0.176, Median: -1.391, Q-Network Loss: 0.005
# Step 824, Avg. Returns: -1.365 +/- 0.155, Median: -1.423, Q-Network Loss: 0.002
# Step 825, Avg. Returns: -1.420 +/- 0.134, Median: -1.446, Q-Network Loss: 0.004
# Step 826, Avg. Returns: -1.331 +/- 0.150, Median: -1.350, Q-Network Loss: 0.005
# Step 827, Avg. Returns: -1.397 +/- 0.142, Median: -1.454, Q-Network Loss: 0.004
# Step 828, Avg. Returns: -1.325 +/- 0.172, Median: -1.338, Q-Network Loss: 0.002
# Step 829, Avg. Returns: -1.279 +/- 0.169, Median: -1.261, Q-Network Loss: 0.001
# Step 830, Avg. Returns: -1.316 +/- 0.151, Median: -1.339, Q-Network Loss: 0.001
# Step 831, Avg. Returns: -1.352 +/- 0.164, Median: -1.424, Q-Network Loss: 0.001
# Step 832, Avg. Returns: -1.388 +/- 0.121, Median: -1.407, Q-Network Loss: 0.001
# Step 833, Avg. Returns: -1.357 +/- 0.165, Median: -1.353, Q-Network Loss: 0.001
# Step 834, Avg. Returns: -1.396 +/- 0.142, Median: -1.414, Q-Network Loss: 0.001
# Step 835, Avg. Returns: -1.398 +/- 0.168, Median: -1.437, Q-Network Loss: 0.002
# Step 836, Avg. Returns: -1.373 +/- 0.162, Median: -1.408, Q-Network Loss: 0.002
# Step 837, Avg. Returns: -1.351 +/- 0.177, Median: -1.420, Q-Network Loss: 0.001
# Step 838, Avg. Returns: -1.389 +/- 0.161, Median: -1.416, Q-Network Loss: 0.002
# Step 839, Avg. Returns: -1.453 +/- 0.057, Median: -1.445, Q-Network Loss: 0.001
# Step 840, Avg. Returns: -1.364 +/- 0.160, Median: -1.352, Q-Network Loss: 0.001
# Step 841, Avg. Returns: -1.335 +/- 0.157, Median: -1.330, Q-Network Loss: 0.001
# Step 842, Avg. Returns: -1.459 +/- 0.095, Median: -1.480, Q-Network Loss: 0.000
# Step 843, Avg. Returns: -1.339 +/- 0.147, Median: -1.345, Q-Network Loss: 0.005
# Step 844, Avg. Returns: -1.428 +/- 0.154, Median: -1.445, Q-Network Loss: 0.001
# Step 845, Avg. Returns: -1.375 +/- 0.138, Median: -1.397, Q-Network Loss: 0.000
# Step 846, Avg. Returns: -1.385 +/- 0.189, Median: -1.429, Q-Network Loss: 0.000
# Step 847, Avg. Returns: -1.408 +/- 0.093, Median: -1.410, Q-Network Loss: 0.000
# Step 848, Avg. Returns: -1.365 +/- 0.134, Median: -1.397, Q-Network Loss: 0.001
# Step 849, Avg. Returns: -1.368 +/- 0.140, Median: -1.405, Q-Network Loss: 0.004
# Step 850, Avg. Returns: -1.451 +/- 0.126, Median: -1.474, Q-Network Loss: 0.000
# Step 851, Avg. Returns: -1.423 +/- 0.201, Median: -1.508, Q-Network Loss: 0.000
# Step 852, Avg. Returns: -1.447 +/- 0.159, Median: -1.462, Q-Network Loss: 0.000
# Step 853, Avg. Returns: -1.433 +/- 0.102, Median: -1.452, Q-Network Loss: 0.001
# Step 854, Avg. Returns: -1.361 +/- 0.177, Median: -1.456, Q-Network Loss: 0.000
# Step 855, Avg. Returns: -1.446 +/- 0.079, Median: -1.458, Q-Network Loss: 0.001
# Step 856, Avg. Returns: -1.451 +/- 0.084, Median: -1.477, Q-Network Loss: 0.000
# Step 857, Avg. Returns: -1.399 +/- 0.169, Median: -1.465, Q-Network Loss: 0.000
# Step 858, Avg. Returns: -1.342 +/- 0.124, Median: -1.377, Q-Network Loss: 0.000
# Step 952, Avg. Returns: -1.152 +/- 0.276, Median: -1.063, Q-Network Loss: 0.000
# Step 953, Avg. Returns: -1.006 +/- 0.267, Median: -0.973, Q-Network Loss: 0.000
# Step 954, Avg. Returns: -1.194 +/- 0.244, Median: -1.107, Q-Network Loss: 0.000
# Step 955, Avg. Returns: -1.178 +/- 0.285, Median: -1.151, Q-Network Loss: 0.003
# Step 956, Avg. Returns: -1.216 +/- 0.231, Median: -1.152, Q-Network Loss: 0.000
# Step 957, Avg. Returns: -1.030 +/- 0.270, Median: -0.921, Q-Network Loss: 0.000
# Step 958, Avg. Returns: -1.147 +/- 0.384, Median: -1.127, Q-Network Loss: 0.000
# Step 959, Avg. Returns: -1.152 +/- 0.245, Median: -1.036, Q-Network Loss: 0.000
# Step 960, Avg. Returns: -1.034 +/- 0.240, Median: -0.995, Q-Network Loss: 0.000
# Step 961, Avg. Returns: -1.187 +/- 0.212, Median: -1.136, Q-Network Loss: 0.000
# Step 962, Avg. Returns: -1.051 +/- 0.248, Median: -1.080, Q-Network Loss: 0.000
# Step 963, Avg. Returns: -1.125 +/- 0.243, Median: -1.056, Q-Network Loss: 0.000
# Step 964, Avg. Returns: -1.305 +/- 0.242, Median: -1.357, Q-Network Loss: 0.001
# Step 965, Avg. Returns: -1.110 +/- 0.284, Median: -1.065, Q-Network Loss: 0.000
# Step 966, Avg. Returns: -1.156 +/- 0.280, Median: -1.057, Q-Network Loss: 0.000
# Step 967, Avg. Returns: -1.165 +/- 0.323, Median: -1.198, Q-Network Loss: 0.000
# Step 968, Avg. Returns: -1.222 +/- 0.236, Median: -1.199, Q-Network Loss: 0.000
# Step 969, Avg. Returns: -1.216 +/- 0.287, Median: -1.194, Q-Network Loss: 0.000
# Step 970, Avg. Returns: -1.114 +/- 0.336, Median: -1.075, Q-Network Loss: 0.000
# Step 971, Avg. Returns: -0.920 +/- 0.530, Median: -0.951, Q-Network Loss: 0.000
# Step 972, Avg. Returns: -1.083 +/- 0.474, Median: -1.397, Q-Network Loss: 0.001
# Step 973, Avg. Returns: -1.253 +/- 0.495, Median: -1.470, Q-Network Loss: 0.000
# Step 974, Avg. Returns: -0.966 +/- 0.696, Median: -1.284, Q-Network Loss: 0.000
# Step 975, Avg. Returns: -0.923 +/- 0.749, Median: -1.363, Q-Network Loss: 0.002
# Step 976, Avg. Returns: -0.925 +/- 0.714, Median: -1.295, Q-Network Loss: 0.000
# Step 977, Avg. Returns: -0.945 +/- 0.821, Median: -1.326, Q-Network Loss: 0.001
# Step 978, Avg. Returns: -0.236 +/- 1.223, Median: -1.014, Q-Network Loss: 0.000
# Step 979, Avg. Returns: 0.217 +/- 1.248, Median: 0.121, Q-Network Loss: 0.000
# Step 980, Avg. Returns: 0.184 +/- 1.406, Median: -0.474, Q-Network Loss: 0.000
# Step 981, Avg. Returns: -0.615 +/- 0.865, Median: -0.501, Q-Network Loss: 0.000
# Step 982, Avg. Returns: -0.222 +/- 1.417, Median: -0.225, Q-Network Loss: 0.000
# Step 983, Avg. Returns: 1.074 +/- 1.694, Median: 1.085, Q-Network Loss: 0.002
# Step 984, Avg. Returns: 1.450 +/- 2.214, Median: 0.028, Q-Network Loss: 0.001
# Step 985, Avg. Returns: 0.655 +/- 1.857, Median: 0.061, Q-Network Loss: 0.000
# Step 986, Avg. Returns: 4.974 +/- 9.982, Median: 0.140, Q-Network Loss: 0.009
# Step 987, Avg. Returns: 15.481 +/- 23.691, Median: 0.304, Q-Network Loss: 0.018
# Step 988, Avg. Returns: 14.443 +/- 33.253, Median: 0.242, Q-Network Loss: 0.015
# Step 989, Avg. Returns: 24.236 +/- 32.278, Median: 0.329, Q-Network Loss: 0.064
# Step 990, Avg. Returns: 32.034 +/- 46.814, Median: 0.317, Q-Network Loss: 0.223
# Step 991, Avg. Returns: 26.052 +/- 30.158, Median: 0.458, Q-Network Loss: 0.150
# Step 992, Avg. Returns: 18.661 +/- 34.636, Median: 0.236, Q-Network Loss: 0.103
# Step 993, Avg. Returns: 36.406 +/- 45.127, Median: 3.840, Q-Network Loss: 0.032
# Step 994, Avg. Returns: 32.148 +/- 46.275, Median: 0.317, Q-Network Loss: 0.128
# Step 995, Avg. Returns: 23.450 +/- 34.254, Median: 0.273, Q-Network Loss: 0.116
# Step 996, Avg. Returns: 57.428 +/- 55.871, Median: 42.668, Q-Network Loss: 0.007
# Step 997, Avg. Returns: 59.986 +/- 82.759, Median: 50.098, Q-Network Loss: 0.140
# Step 998, Avg. Returns: 36.255 +/- 25.641, Median: 49.060, Q-Network Loss: 0.031
# Step 999, Avg. Returns: 36.235 +/- 34.744, Median: 45.650, Q-Network Loss: 0.147

# %%
env.close()

# %% [markdown]
# Let's visualize the policy we learned:

# %%
env = gym.make("MetaDrive-topdown", config={"use_render": True, "horizon": 500, "num_scenarios": 100})
transitions = collect_trajectory(env, QPolicy(primary_q_network, epsilon=0.0))
env.close()

rew = [t.reward for t in transitions]

print("Reward:", sum(rew))
env.close()
# Out:
# Reward: 114.80912859523201

# %% [markdown]
# For us, the learned policy consisted pretty much of just going straight at full speed. This is because the agent is rewarded for moving forward. After training more episodes, DDQN may learn to steer around corners - but two hundred timesteps won't get us there.

# %%
import matplotlib.pyplot as plt

def moving_average(x: list[float], window_size: int) -> list[float]:
    """
    Compute the moving average of the given list
    """
    return [np.mean(x[i:i+window_size]) for i in range(len(x) - window_size + 1)]

return_medians = [np.median(returns[i]) for i in range(len(returns))]
return_means = [np.mean(returns[i]) for i in range(len(returns))]
return_stds = [np.std(returns[i]) for i in range(len(returns))]
plt.plot(return_medians, label="Median")
plt.plot(return_means, label="Mean")
plt.fill_between(range(len(return_means)), np.array(return_means) - np.array(return_stds), np.array(return_means) + np.array(return_stds), alpha=0.3)
plt.xlabel("Epoch")
plt.ylabel("Average Return")
plt.legend()
plt.show()

# %%
# scatter plot of the returns
xs = []
ys = []
for t, rets in enumerate(returns):
    for ret in rets:
        xs.append(t)
        ys.append(ret)
plt.scatter(xs, ys, alpha=0.2)
