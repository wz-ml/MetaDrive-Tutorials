# %% [markdown]
# ## DDQN Implementation Exercise
# Before beginning this exercise, we highly recommend you read through the [Double DQN Derivation](double_dqn.ipynb) tutorial to get a better grasp of the math behind Double DQN (DDQN).

# %% [markdown]
# Since we've already covered most of this in the DQN exercise, we'll copy all the unchanged code over without explanation. You're encouraged to read through the code again to refresh your memory.

# %%
import metadrive  # Import this package to register the environment!
import gymnasium as gym
from metadrive.envs.top_down_env import TopDownMetaDrive
gym.register(id="MetaDrive-topdown", entry_point=TopDownMetaDrive, kwargs=dict(config={}))
# Out:
# Successfully registered the following environments: ['MetaDrive-validation-v0', 'MetaDrive-10env-v0', 'MetaDrive-100envs-v0', 'MetaDrive-1000envs-v0', 'SafeMetaDrive-validation-v0', 'SafeMetaDrive-10env-v0', 'SafeMetaDrive-100envs-v0', 'SafeMetaDrive-1000envs-v0', 'MARLTollgate-v0', 'MARLBottleneck-v0', 'MARLRoundabout-v0', 'MARLIntersection-v0', 'MARLParkingLot-v0', 'MARLMetaDrive-v0'].

# %%
import numpy as np
import numpy.typing as npt

NUM_ACTIONS = 5

def discrete2continuous(action:int) -> npt.NDArray[np.float32]:
    """
    Convert discrete action to continuous action
    """
    assert 0 <= action < NUM_ACTIONS
    throttle_magnitude = 1.0
    brake_magnitude = 1.0
    steering_magnitude = 1.0
    match action:
        case 0:
            return np.array([steering_magnitude, 0.0])
        case 1:
            return np.array([0.0, throttle_magnitude])
        case 2:
            return np.array([0.0, -brake_magnitude])
        case 3:
            return np.array([-steering_magnitude, 0.0])
        case 4:
            return np.array([0.0, 0.0])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Q network
class QNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        # input is size 84x84x5
        # output is size NUM_ACTIONS

        # TODO: Define the layers of the network, with two convolutional layers and one fully connected layer

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: Implement the forward pass of the network using the layers you defined in __init__

        return x

# %%
def obs_batch_to_tensor(obs: list[npt.NDArray[np.float32]], device: torch.device) -> torch.Tensor:
    """
    Reshape the image observation from (B, H, W, C) to (B, C, H, W) and convert it to a tensor
    """
    return torch.tensor(np.stack(obs), dtype=torch.float32, device=device).permute(0, 3, 1, 2)

# %%
def deviceof(m: nn.Module) -> torch.device:
    """
    Get the device of the given module
    """
    return next(m.parameters()).device

class QPolicy:
    def __init__(self, net:QNetwork, epsilon: float = 0.0):
        self.net = net
        self.epsilon = epsilon
    
    def __call__(self, obs: npt.NDArray[np.float32]) -> int:
        """
        Return action given observation using the epsilon-greedy policy
        """
        # TODO: Implement the epsilon-greedy policy using np.random.rand() and torch.argmax()
        # Remember to use torch.no_grad() when computing the Q values so we don't spend time computing gradients

# %%
import typing

class Transition(typing.NamedTuple):
    obs: npt.NDArray[np.float32]
    action: int
    reward: float
    next_obs: npt.NDArray[np.float32]
    terminated: bool


def collect_trajectory(env:gym.Env, policy:typing.Callable[[npt.NDArray], int]) -> list[Transition]:
    """
    Collect a trajectory from the environment using the given policy
    """
    trajectory = []

    obs, info = env.reset()

    while True:
        action = policy(obs)
        next_obs, reward, terminated, truncated, info = env.step(discrete2continuous(action))
        trajectory.append(Transition(obs, action, reward, next_obs, terminated))
        if terminated or truncated:
            break
        else:
            obs = next_obs

    return trajectory

# %%
import random
class ReplayBuffer():
    def __init__(self, capacity:int = 10000):
        self.capacity = capacity
        self.buffer: list[Transition] = []
        self.position = 0

    def push(self, transition: Transition):
        if len(self.buffer) < self.capacity:
            self.buffer.append(transition)
        else:
            self.buffer[self.position] = transition
        # Overwrite the earliest stuff if the buffer is full.
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size:int) -> list[Transition]:
        return random.sample(self.buffer, batch_size)

    def __len__(self) -> int:
        return len(self.buffer)

# %% [markdown]
# ## Double DQN
#
# *Note: We implement the version of DDQN as described by [Hasselt et al. (2015)](https://arxiv.org/abs/1509.06461).*
#
# The key issue with DQNs (as we saw in the previous exercise) is that the max operation in the target Q value calculation is susceptible to overestimation. To address this issue, DDQN proposes to introduce two separate networks: a **primary network** (denoted by $Q_{\phi}$) and a **target network** (denoted by $Q_{\phi_{\text{target}}}$). The primary network is used for action selection, and the target network is used for action evaluation. The target network is updated less frequently than the action network.
#
# The idea is that the primary network will learn to predict the Q-Values for the policy defined by the target network. This also helps eliminate the moving target problem, since the target network is only updated periodically.
#
# #### DDQN Network Update Rule
#
# For:
# * Terminal pairs: $Q_{\text{target}}(s, a) = r$
# * Non-terminal pairs: $Q_{\text{target}}(s, a) = r + \gamma Q_{\phi_{\text{target}}}(s', \underset{a' \in A}{\operatorname{argmax}} \, Q_{\phi}(s', a'))$
#
# We train the primary network to more closely match the target q-values by minimizing the following loss function:
# $$
# \mathcal{L}(\phi) = \mathbb{E}_{s, a, r, s'} \left[ \left( Q_{\phi}(s, a) - Q_{\text{target}}(s, a) \right)^2 \right]
# $$

# %%
def compute_target_q_values(
        primary_q_network: QNetwork,
        target_q_network: QNetwork,
        rewards: list[float],
        next_observations: list[npt.NDArray[np.float32]],
        terminateds: list[bool],
        gamma: float
) -> list[float]:
    """
    Compute the target Q values for the transitions
    """
    # assert that the lengths of the lists are the same
    n_transitions = len(rewards)
    assert len(next_observations) == n_transitions
    assert len(terminateds) == n_transitions

    # assert that primary and target networks are on the same device
    device = deviceof(primary_q_network)
    assert deviceof(target_q_network) == device

    # TODO: compute the Q_target(s', a') values
    # Remember to use torch.no_grad
    primary_next_q_values = 
    target_next_q_values =

    # TODO: compute argmax_a' Q_phi(s', a') for each transition
    argmax_next_q_values 

    # TODO: compute the Q_phi_target(s', argmax_a' Q_phi(s', a')) values
    max_next_q_values = 
    
    # TODO: compute the target Q values
    target_q_values = []
    for reward, terminated, max_next_q_value in zip(rewards, terminateds, max_next_q_values):
        if terminated: 
            # TODO: 

        else:
            # TODO: 
    return target_q_values

# %% [markdown]
# We train the Q-Network to try to predict these target Q values. We use MSE loss to train the network, but another popular choice is Huber loss.

# %%
def train_primary_q_network(
        primary_q_network: QNetwork,
        target_q_network: QNetwork,
        optimizer: torch.optim.Optimizer,
        transitions: list[Transition],
        gamma: float
) -> float:
    """
    Train the Q network using the given transitions
    """
    # unpack the transitions
    obs_batch, action_batch, reward_batch, next_obs_batch, terminated_batch = zip(*transitions)
    
    device = deviceof(primary_q_network)

    # compute the target Q values
    target_q_values = compute_target_q_values(primary_q_network, target_q_network, reward_batch, next_obs_batch, terminated_batch, gamma)
    target_q_values_tensor = torch.tensor(target_q_values, dtype=torch.float32, device=device)

    # compute the Q values for the picked actions
    obs_batch = obs_batch_to_tensor(obs_batch, device)
    all_q_values = primary_q_network(obs_batch)
    q_values = all_q_values[range(len(action_batch)), action_batch]

    # compute the loss
    loss = F.mse_loss(q_values, target_q_values_tensor)

    # perform gradient descent
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return float(loss)

def soft_update_target_q_network(primary_q_network: QNetwork, target_q_network: QNetwork, tau: float):
    """
    Soft update the target Q network
    """
    # assert that primary and target networks are on the same device
    device = deviceof(primary_q_network)
    assert deviceof(target_q_network) == device

    # update the target network parameters
    # TODO: use the soft update rule described in the double_and_dueling_dqn.ipynb notebook to update the target network parameters
    for primary_param, target_param in zip(primary_q_network.parameters(), target_q_network.parameters()):
        target_param.data.copy_(...)

# %% [markdown]
# ### Training Loop

# %% [markdown]
# Now, we can finally begin training the network.

# %%
# disable logging from metadrive
import logging
import inspect
import metadrive.envs.top_down_env
logging.getLogger(inspect.getfile(metadrive.envs.base_env)).setLevel(logging.WARNING)

# %%
def set_lr(optimizer: torch.optim.Optimizer, lr: float) -> None:
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

primary_q_network = QNetwork().to(device)
target_q_network = QNetwork().to(device)

q_optimizer = torch.optim.Adam(primary_q_network.parameters())

policy = QPolicy(primary_q_network, epsilon=0.3)

replay_buffer = ReplayBuffer()

step = 0
returns = []
losses = []

# %%
env = gym.make("MetaDrive-topdown", config={"use_render": False, "horizon": 300, "num_scenarios": 100})
# Out:
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:29: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: float32. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:34: UserWarning: WARN: It seems a Box observation space is an image but the lower and upper bounds are not [0, 255]. Actual lower bound: -0.0, upper bound: 1.0. Generally, CNN policies assume observations are within that range, so you may encounter an issue if the observation values are not.
#   logger.warn(

# %%
TRAIN_EPOCHS = 200
EPISODES_PER_BATCH = 8
GAMMA = 0.80
TAU = 1e-2
set_lr(q_optimizer, 1e-4)

# Train
while step < TRAIN_EPOCHS:
    trajectory_returns = []

    for _ in range(EPISODES_PER_BATCH):
        # Collect trajectory
        transitions = collect_trajectory(env, policy)
        rew_traj = [t.reward for t in transitions]

        # Update replay buffer
        for t in transitions:
            replay_buffer.push(t)

        # Update trajectory returns
        trajectory_returns.append(sum(rew_traj))

    loss = train_primary_q_network(
        primary_q_network,
        target_q_network,
        q_optimizer,
        replay_buffer.sample(EPISODES_PER_BATCH),
        GAMMA
    )
    soft_update_target_q_network(primary_q_network, target_q_network, TAU)

    # slowly decay the epsilon
    policy.epsilon = policy.epsilon * 0.97

    # collect statistics
    returns.append(trajectory_returns)
    losses.append(loss)

    print(f"Step {step}, Avg. Returns: {np.mean(trajectory_returns):.3f} +/- {np.std(trajectory_returns):.3f}, Median: {np.median(trajectory_returns):.3f}, Q-Network Loss: {losses[-1]:.3f}")

    step += 1
# Out:
# Step 100, Avg. Returns: 83.948 +/- 59.844, Median: 59.624, Q-Network Loss: 0.374
# Step 101, Avg. Returns: 55.617 +/- 9.311, Median: 54.544, Q-Network Loss: 0.227
# Step 102, Avg. Returns: 108.718 +/- 70.454, Median: 88.576, Q-Network Loss: 0.301
# Step 103, Avg. Returns: 75.977 +/- 31.404, Median: 66.217, Q-Network Loss: 5.796
# Step 104, Avg. Returns: 141.935 +/- 84.027, Median: 143.918, Q-Network Loss: 0.406
# Step 105, Avg. Returns: 109.825 +/- 45.886, Median: 96.963, Q-Network Loss: 0.462
# Step 106, Avg. Returns: 106.430 +/- 36.586, Median: 97.139, Q-Network Loss: 0.347
# Step 107, Avg. Returns: 100.495 +/- 73.608, Median: 64.723, Q-Network Loss: 0.279
# Step 108, Avg. Returns: 80.429 +/- 47.904, Median: 59.294, Q-Network Loss: 0.471
# Step 109, Avg. Returns: 86.293 +/- 38.725, Median: 83.389, Q-Network Loss: 0.435
# Step 110, Avg. Returns: 84.556 +/- 36.780, Median: 72.777, Q-Network Loss: 0.220
# Step 111, Avg. Returns: 97.108 +/- 66.684, Median: 72.548, Q-Network Loss: 0.310
# Step 112, Avg. Returns: 87.459 +/- 35.524, Median: 87.803, Q-Network Loss: 0.302
# Step 113, Avg. Returns: 73.370 +/- 30.265, Median: 58.364, Q-Network Loss: 0.168
# Step 114, Avg. Returns: 76.409 +/- 50.203, Median: 56.694, Q-Network Loss: 0.300
# Step 115, Avg. Returns: 55.871 +/- 5.560, Median: 55.575, Q-Network Loss: 0.154
# Step 116, Avg. Returns: 59.510 +/- 11.076, Median: 54.963, Q-Network Loss: 0.216
# Step 117, Avg. Returns: 105.244 +/- 54.393, Median: 101.439, Q-Network Loss: 0.174
# Step 118, Avg. Returns: 75.330 +/- 28.279, Median: 73.006, Q-Network Loss: 0.270
# Step 119, Avg. Returns: 82.817 +/- 36.087, Median: 70.646, Q-Network Loss: 0.193
# Step 120, Avg. Returns: 77.223 +/- 24.429, Median: 72.531, Q-Network Loss: 0.153
# Step 121, Avg. Returns: 70.615 +/- 24.574, Median: 66.404, Q-Network Loss: 0.303
# Step 122, Avg. Returns: 94.242 +/- 39.039, Median: 80.489, Q-Network Loss: 0.198
# Step 123, Avg. Returns: 113.363 +/- 43.283, Median: 122.639, Q-Network Loss: 0.172
# Step 124, Avg. Returns: 85.828 +/- 42.788, Median: 58.348, Q-Network Loss: 0.202
# Step 125, Avg. Returns: 76.711 +/- 36.551, Median: 58.202, Q-Network Loss: 0.100
# Step 126, Avg. Returns: 78.229 +/- 34.121, Median: 65.770, Q-Network Loss: 0.159
# Step 127, Avg. Returns: 98.516 +/- 41.915, Median: 96.424, Q-Network Loss: 0.370
# Step 128, Avg. Returns: 131.410 +/- 49.290, Median: 146.519, Q-Network Loss: 0.157
# Step 129, Avg. Returns: 107.647 +/- 50.739, Median: 122.765, Q-Network Loss: 0.274
# Step 130, Avg. Returns: 82.113 +/- 31.725, Median: 68.897, Q-Network Loss: 0.174
# Step 131, Avg. Returns: 77.832 +/- 31.825, Median: 61.920, Q-Network Loss: 5.826
# Step 132, Avg. Returns: 113.746 +/- 49.967, Median: 114.047, Q-Network Loss: 5.175
# Step 133, Avg. Returns: 103.265 +/- 43.406, Median: 89.430, Q-Network Loss: 0.261
# Step 134, Avg. Returns: 81.494 +/- 40.823, Median: 59.128, Q-Network Loss: 0.232
# Step 135, Avg. Returns: 103.462 +/- 41.265, Median: 94.531, Q-Network Loss: 0.363
# Step 136, Avg. Returns: 103.973 +/- 50.125, Median: 109.369, Q-Network Loss: 0.294
# Step 137, Avg. Returns: 81.321 +/- 43.477, Median: 61.831, Q-Network Loss: 5.667
# Step 138, Avg. Returns: 126.545 +/- 88.269, Median: 87.171, Q-Network Loss: 0.435
# Step 139, Avg. Returns: 105.298 +/- 49.550, Median: 90.555, Q-Network Loss: 0.376
# Step 140, Avg. Returns: 75.886 +/- 20.565, Median: 65.779, Q-Network Loss: 0.418
# Step 141, Avg. Returns: 83.300 +/- 42.016, Median: 65.366, Q-Network Loss: 0.230
# Step 142, Avg. Returns: 78.501 +/- 51.176, Median: 55.523, Q-Network Loss: 0.296
# Step 143, Avg. Returns: 67.026 +/- 36.271, Median: 53.432, Q-Network Loss: 5.170
# Step 144, Avg. Returns: 83.831 +/- 40.479, Median: 60.887, Q-Network Loss: 0.343
# Step 145, Avg. Returns: 105.470 +/- 46.487, Median: 112.046, Q-Network Loss: 0.359
# Step 146, Avg. Returns: 68.388 +/- 32.982, Median: 58.758, Q-Network Loss: 0.277
# Step 147, Avg. Returns: 94.992 +/- 47.094, Median: 70.942, Q-Network Loss: 0.177
# Step 148, Avg. Returns: 55.564 +/- 14.422, Median: 51.497, Q-Network Loss: 0.257
# Step 149, Avg. Returns: 99.767 +/- 48.470, Median: 78.097, Q-Network Loss: 0.179
# Step 150, Avg. Returns: 97.615 +/- 39.271, Median: 91.531, Q-Network Loss: 0.249
# Step 151, Avg. Returns: 64.827 +/- 33.637, Median: 54.155, Q-Network Loss: 0.311
# Step 152, Avg. Returns: 107.457 +/- 68.604, Median: 85.438, Q-Network Loss: 0.266
# Step 153, Avg. Returns: 98.859 +/- 92.651, Median: 60.879, Q-Network Loss: 0.156
# Step 154, Avg. Returns: 98.547 +/- 49.704, Median: 68.113, Q-Network Loss: 0.165
# Step 155, Avg. Returns: 65.363 +/- 26.139, Median: 55.198, Q-Network Loss: 4.059
# Step 156, Avg. Returns: 145.032 +/- 100.883, Median: 99.477, Q-Network Loss: 0.079
# Step 157, Avg. Returns: 91.257 +/- 40.746, Median: 96.713, Q-Network Loss: 0.149
# Step 158, Avg. Returns: 95.224 +/- 39.700, Median: 89.430, Q-Network Loss: 0.206
# Step 159, Avg. Returns: 97.896 +/- 32.049, Median: 93.454, Q-Network Loss: 0.361
# Step 160, Avg. Returns: 109.378 +/- 45.473, Median: 86.793, Q-Network Loss: 0.199
# Step 161, Avg. Returns: 77.871 +/- 41.839, Median: 58.509, Q-Network Loss: 0.168
# Step 162, Avg. Returns: 86.165 +/- 36.052, Median: 74.206, Q-Network Loss: 0.176
# Step 163, Avg. Returns: 102.498 +/- 44.452, Median: 102.203, Q-Network Loss: 0.146
# Step 164, Avg. Returns: 106.821 +/- 94.439, Median: 61.538, Q-Network Loss: 0.232
# Step 165, Avg. Returns: 111.966 +/- 90.081, Median: 80.204, Q-Network Loss: 0.164
# Step 166, Avg. Returns: 89.363 +/- 43.056, Median: 70.052, Q-Network Loss: 0.188
# Step 167, Avg. Returns: 89.911 +/- 36.690, Median: 69.656, Q-Network Loss: 0.120
# Step 168, Avg. Returns: 71.937 +/- 19.933, Median: 72.300, Q-Network Loss: 0.115
# Step 169, Avg. Returns: 98.130 +/- 50.542, Median: 85.052, Q-Network Loss: 0.255
# Step 170, Avg. Returns: 82.240 +/- 28.995, Median: 70.765, Q-Network Loss: 0.080
# Step 171, Avg. Returns: 73.213 +/- 43.682, Median: 58.509, Q-Network Loss: 0.092
# Step 172, Avg. Returns: 125.075 +/- 44.333, Median: 129.748, Q-Network Loss: 0.118
# Step 173, Avg. Returns: 80.214 +/- 40.691, Median: 67.621, Q-Network Loss: 3.988
# Step 174, Avg. Returns: 79.553 +/- 32.829, Median: 64.756, Q-Network Loss: 0.205
# Step 175, Avg. Returns: 73.755 +/- 32.813, Median: 59.698, Q-Network Loss: 0.110
# Step 176, Avg. Returns: 59.649 +/- 11.380, Median: 61.497, Q-Network Loss: 6.284
# Step 177, Avg. Returns: 86.976 +/- 41.755, Median: 66.570, Q-Network Loss: 0.077
# Step 178, Avg. Returns: 100.483 +/- 55.123, Median: 74.518, Q-Network Loss: 0.155
# Step 179, Avg. Returns: 86.485 +/- 43.467, Median: 55.505, Q-Network Loss: 0.020
# Step 180, Avg. Returns: 78.088 +/- 36.360, Median: 66.109, Q-Network Loss: 0.051
# Step 181, Avg. Returns: 115.275 +/- 52.787, Median: 107.697, Q-Network Loss: 0.012
# Step 182, Avg. Returns: 93.300 +/- 36.832, Median: 87.420, Q-Network Loss: 0.232
# Step 183, Avg. Returns: 89.457 +/- 40.938, Median: 78.292, Q-Network Loss: 0.399
# Step 184, Avg. Returns: 77.924 +/- 34.890, Median: 56.153, Q-Network Loss: 0.141
# Step 185, Avg. Returns: 80.357 +/- 31.086, Median: 75.060, Q-Network Loss: 5.696
# Step 186, Avg. Returns: 113.575 +/- 69.948, Median: 92.695, Q-Network Loss: 5.982
# Step 187, Avg. Returns: 88.081 +/- 41.677, Median: 66.296, Q-Network Loss: 0.131
# Step 188, Avg. Returns: 107.622 +/- 49.831, Median: 102.798, Q-Network Loss: 0.252
# Step 189, Avg. Returns: 135.170 +/- 87.912, Median: 122.540, Q-Network Loss: 5.558
# Step 190, Avg. Returns: 81.700 +/- 44.726, Median: 55.931, Q-Network Loss: 0.148
# Step 191, Avg. Returns: 150.336 +/- 84.629, Median: 136.138, Q-Network Loss: 0.233
# Step 192, Avg. Returns: 81.892 +/- 44.299, Median: 67.699, Q-Network Loss: 0.067
# Step 193, Avg. Returns: 113.497 +/- 43.909, Median: 102.734, Q-Network Loss: 0.690
# Step 194, Avg. Returns: 90.844 +/- 48.834, Median: 55.930, Q-Network Loss: 5.702
# Step 195, Avg. Returns: 97.270 +/- 40.347, Median: 73.841, Q-Network Loss: 0.259
# Step 196, Avg. Returns: 109.655 +/- 40.873, Median: 113.938, Q-Network Loss: 0.269
# Step 197, Avg. Returns: 126.724 +/- 43.611, Median: 136.200, Q-Network Loss: 0.252
# Step 198, Avg. Returns: 71.622 +/- 30.790, Median: 62.797, Q-Network Loss: 0.163
# Step 199, Avg. Returns: 73.886 +/- 32.028, Median: 66.481, Q-Network Loss: 0.349

# %%
env.close()

# %% [markdown]
# Let's visualize the policy we learned:

# %%
env = gym.make("MetaDrive-topdown", config={"use_render": True, "horizon": 500, "num_scenarios": 100})
transitions = collect_trajectory(env, QPolicy(primary_q_network, epsilon=0.0))
env.close()

rew = [t.reward for t in transitions]

print("Reward:", sum(rew))
# Out:
# Known pipe types:
#   glxGraphicsPipe
# (1 aux display modules not yet loaded.)
# :task(warning): Creating implicit AsyncTaskChain default for AsyncTaskManager TaskManager
# Reward: 64.83419519862899

# %% [markdown]
# For us, the learned policy consisted pretty much of just going straight at full speed. This is because the agent is rewarded for moving forward. DQN never learned to steer.

# %%
import matplotlib.pyplot as plt

def moving_average(x: list[float], window_size: int) -> list[float]:
    """
    Compute the moving average of the given list
    """
    return [np.mean(x[i:i+window_size]) for i in range(len(x) - window_size + 1)]

return_medians = [np.median(returns[i]) for i in range(len(returns))]
return_means = [np.mean(returns[i]) for i in range(len(returns))]
return_stds = [np.std(returns[i]) for i in range(len(returns))]
plt.plot(return_medians, label="Median")
plt.plot(return_means, label="Mean")
plt.fill_between(range(len(return_means)), np.array(return_means) - np.array(return_stds), np.array(return_means) + np.array(return_stds), alpha=0.3)
plt.xlabel("Epoch")
plt.ylabel("Average Return")
plt.legend()
plt.show()

# %%
# scatter plot of the returns
xs = []
ys = []
for t, rets in enumerate(returns):
    for ret in rets:
        xs.append(t)
        ys.append(ret)
plt.scatter(xs, ys, alpha=0.2)

# %% [markdown]
# ## Implementing a Double Dueling DQN
# That's right! We can stack both improvements on top of each other to achieve unparalleled performance (for what you've learned so far). As the methodologies are independent, we can implement both **advantage-value separation** and primary/target network separation simultaneously.
#
# Recall from the [Double/Dueling DQN Notebook](double_and_dueling_dqn.ipynb) that our Q-value function can be broken down into the advantage function (which takes in a state-action pair) and the value function (which takes in a state).
# $$Q^{\pi}(s,a) = A^{\pi}(s, a) + V^{\pi}(s)$$
#
# We also went over how we might implement an advantage function and a value function simultaneously within the same network by creating two heads. Let's do that below:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Q network for a dueling dqn
class QNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        # input is size 84x84x5
        # output is size NUM_ACTIONS
        self.conv1 = nn.Conv2d(5, 16, kernel_size=8, stride=4) # 84x84x5 -> 20x20x16
        self.conv2 = nn.Conv2d(16, 32, kernel_size=4, stride=2) # 20x20x16 -> 9x9x32
        self.fc1 = nn.Linear(9*9*32, 256) # 9x9x32 -> 256

        # TODO: Define the layers for the advantage head and the value head

# %% [markdown]
# Recall how we calculate our Q-value:
# $$Q^{\pi}(s,a) = V^{\pi}(s) + \left[A^{\pi}(s, a) - \underset{a \in A}{\operatorname{max}} \space A_t^{\pi}(s, a)\right]$$

# %%
def forward(self, x: torch.Tensor) -> torch.Tensor:
    x = F.relu(self.conv1(x)) # Bx84x84x5 -> Bx20x20x16
    x = F.relu(self.conv2(x)) # Bx20x20x16 -> Bx9x9x32
    x = torch.flatten(x, start_dim=1) # Bx9x9x32 -> Bx9*9*32
    x = F.relu(self.fc1(x)) # Bx9*9*32 -> Bx256
    # TODO: Compute the advantage and value outputs
    # Advantage output should be BxNUM_ACTIONS
    # Value output should be Bx1
    return ...
QNetwork.forward = forward

# %% [markdown]
# From this point on we can reuse the exact same training code above to train our Double Dueling DQN.

# %%
def compute_target_q_values(
        primary_q_network: QNetwork,
        target_q_network: QNetwork,
        rewards: list[float],
        next_observations: list[npt.NDArray[np.float32]],
        terminateds: list[bool],
        gamma: float
) -> list[float]:
    """
    Compute the target Q values for the transitions
    """
    # assert that the lengths of the lists are the same
    n_transitions = len(rewards)
    assert len(next_observations) == n_transitions
    assert len(terminateds) == n_transitions

    # assert that primary and target networks are on the same device
    device = deviceof(primary_q_network)
    assert deviceof(target_q_network) == device

    # compute the Q_target(s', a') values
    next_obs_batch = obs_batch_to_tensor(next_observations, device)
    with torch.no_grad():
        primary_next_q_values = primary_q_network(next_obs_batch)
        target_next_q_values = target_q_network(next_obs_batch)

    # compute argmax_a' Q_phi(s', a') for each transition
    argmax_next_q_values = torch.max(primary_next_q_values, dim=1).indices

    # compute the Q_phi_target(s', argmax_a' Q_phi(s', a')) values
    max_next_q_values = target_next_q_values[range(n_transitions), argmax_next_q_values]
    
    # compute the target Q values
    target_q_values = []
    for reward, terminated, max_next_q_value in zip(rewards, terminateds, max_next_q_values):
        if terminated:
            target_q_values.append(reward)
        else:
            target_q_values.append(reward + gamma * float(max_next_q_value))

    return target_q_values

def train_primary_q_network(
        primary_q_network: QNetwork,
        target_q_network: QNetwork,
        optimizer: torch.optim.Optimizer,
        transitions: list[Transition],
        gamma: float
) -> float:
    """
    Train the Q network using the given transitions
    """
    # unpack the transitions
    obs_batch, action_batch, reward_batch, next_obs_batch, terminated_batch = zip(*transitions)
    
    device = deviceof(primary_q_network)

    # compute the target Q values
    target_q_values = compute_target_q_values(primary_q_network, target_q_network, reward_batch, next_obs_batch, terminated_batch, gamma)
    target_q_values_tensor = torch.tensor(target_q_values, dtype=torch.float32, device=device)

    # compute the Q values for the picked actions
    obs_batch = obs_batch_to_tensor(obs_batch, device)
    all_q_values = primary_q_network(obs_batch)
    q_values = all_q_values[range(len(action_batch)), action_batch]

    # compute the loss
    loss = F.mse_loss(q_values, target_q_values_tensor)

    # perform gradient descent
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return float(loss)

def soft_update_target_q_network(primary_q_network: QNetwork, target_q_network: QNetwork, tau: float):
    """
    Soft update the target Q network
    """
    # assert that primary and target networks are on the same device
    device = deviceof(primary_q_network)
    assert deviceof(target_q_network) == device

    # update the target network parameters
    for primary_param, target_param in zip(primary_q_network.parameters(), target_q_network.parameters()):
        target_param.data.copy_(tau * primary_param.data + (1 - tau) * target_param.data)

# %%
# disable logging from metadrive
import logging
import inspect
import metadrive.envs.top_down_env
logging.getLogger(inspect.getfile(metadrive.envs.base_env)).setLevel(logging.WARNING)

def set_lr(optimizer: torch.optim.Optimizer, lr: float) -> None:
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

primary_q_network = QNetwork().to(device)
target_q_network = QNetwork().to(device)

q_optimizer = torch.optim.Adam(primary_q_network.parameters())

policy = QPolicy(primary_q_network, epsilon=0.4)

replay_buffer = ReplayBuffer()

step = 0
returns = []
losses = []

# %%
try: env.close()
except: pass
env = gym.make("MetaDrive-topdown", config={"use_render": False, "horizon": 500, "num_scenarios": 100})
# Out:
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:29: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: float32. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:34: UserWarning: WARN: It seems a Box observation space is an image but the lower and upper bounds are not [0, 255]. Actual lower bound: -0.0, upper bound: 1.0. Generally, CNN policies assume observations are within that range, so you may encounter an issue if the observation values are not.
#   logger.warn(

# %%
TRAIN_EPOCHS = 200
EPISODES_PER_BATCH = 8
GAMMA = 0.96
TAU = 1e-2
set_lr(q_optimizer, 5e-5)

# Train
while step < TRAIN_EPOCHS:
    trajectory_returns = []

    for _ in range(EPISODES_PER_BATCH):
        # Collect trajectory
        transitions = collect_trajectory(env, policy)
        rew_traj = [t.reward for t in transitions]

        # Update replay buffer
        for t in transitions:
            replay_buffer.push(t)

        # Update trajectory returns
        trajectory_returns.append(sum(rew_traj))

    loss = train_primary_q_network(
        primary_q_network,
        target_q_network,
        q_optimizer,
        replay_buffer.sample(EPISODES_PER_BATCH),
        GAMMA
    )
    soft_update_target_q_network(primary_q_network, target_q_network, TAU)

    # slowly decay the epsilon
    policy.epsilon = policy.epsilon * 0.99

    # collect statistics
    returns.append(trajectory_returns)
    losses.append(loss)

    print(f"Step {step}, Avg. Returns: {np.mean(trajectory_returns):.3f} +/- {np.std(trajectory_returns):.3f}, Median: {np.median(trajectory_returns):.3f}, Q-Network Loss: {losses[-1]:.3f}")

    step += 1
# Out:
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:210: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(

# %%
env.close()
