# %% [markdown]
# ## DQN & DDQN Implementation Exercise
# Before beginning this exercise, we highly recommend you read through the [DQN Derivation](dqn_derivation.ipynb) tutorial to get a better grasp of the math behind DQN.
#
# Initializing the environment:

# %%
import metadrive  # Import this package to register the environment!
import gymnasium as gym

env = gym.make("MetaDrive-validation-v0", config={"use_render": False})
env = gym.make("MetaDrive-topdown", config={"use_render": True, "horizon": 500, "num_scenarios": 100})

# Alternatively, you can instantiate using the class
# env = metadrive.MetaDriveEnv(config={"use_render": True, "num_scenarios": 100})
# Out:
# Successfully registered the following environments: ['MetaDrive-validation-v0', 'MetaDrive-10env-v0', 'MetaDrive-100envs-v0', 'MetaDrive-1000envs-v0', 'SafeMetaDrive-validation-v0', 'SafeMetaDrive-10env-v0', 'SafeMetaDrive-100envs-v0', 'SafeMetaDrive-1000envs-v0', 'MARLTollgate-v0', 'MARLBottleneck-v0', 'MARLRoundabout-v0', 'MARLIntersection-v0', 'MARLParkingLot-v0', 'MARLMetaDrive-v0'].

# %% [markdown]
# ### Observation space and action space.
#
# Metadrive is built on top of OpenAI Gym, a toolkit developed by OpenAI for developing and benchmarking reinforcement learning models. Metadrive environments are examples of Gym environments. Two major elements of a gym environment that represent your model's input and output dimensions are the *observation space* and the *sample space*.
#
#
# Observation Space: This is the space in which the agent observes the environment. It can be anything that an agent observes - from pixel data on a screen to angles, velocities, raw game states, etc. There are a few types of observation spaces, with the most common ones being Box, Dict, and Discrete. Each of these is a different mode that observation data is represented in.
#
# Action Space: This is the space in which the agent takes actions. The action could be moving left or right, jumping, running, etc. Similar to the observation space, the action space also has a specific type.
#
# More documentation around the Space class can be found [here](https://www.gymlibrary.dev/api/spaces/).
#
# Before we build our model, let's note the range of observations and actions our agent can observe/take.

# %%
obs, info = env.reset()
# Get observation space and action space
print(env.observation_space)
print(env.action_space)
print(info)
# Out:
# c:\Users\william\venvs\metadrive\lib\site-packages\gymnasium\utils\passive_env_checker.py:210: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# Box(-0.0, 1.0, (259,), float32)
# Box(-1.0, 1.0, (2,), float32)
# {'overtake_vehicle_num': 0, 'velocity': 0.0, 'steering': 0.0, 'acceleration': 0.0, 'step_energy': 0.0, 'episode_energy': 0.0, 'policy': 'EnvInputPolicy', 'crash_vehicle': False, 'crash_object': False, 'crash_building': False, 'out_of_road': False, 'arrive_dest': False, 'max_step': False, 'env_seed': 0, 'crash': False, 'step_reward': 0.0, 'cost': 0}

# %%
# Sample code for creating a loop to interact with the environment

"""
env.reset()
for i in range(1000):
    action = env.action_space.sample() # take random action
    obs, reward, terminated, truncated, info = env.step(action)  
    if terminated or truncated:
        env.reset()
env.close()
"""

# reward: scalar
# terminated: bool, whether the episode is terminated
# truncated: bool, whether the episode is truncated
# info: dict, contains additional information
# Out:
# '\nenv.reset()\nfor i in range(1000):\n    obs, reward, terminated, truncated, info = env.step(env.action_space.sample())  # Use random policy\n    if terminated or truncated:\n        env.reset()\nenv.close()\n'

# %% [markdown]
# ### Creating the model

# %%
import torch as t
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random

class DQNModel(nn.Module):
    def __init__(self, observation_size = 259, action_size = 4, hidden_size = 256):
        super().__init__()
        # Create a fully connected network with 3 or more layers using nn.Linear
        # First layer is filled out for you:
        self.fc1 = nn.Linear(observation_size, hidden_size)

        # TODO: Fill out the rest of the network!
        # Hint: All layers except the first and last layers have input shape hidden_size and output shape hidden_size
        # Last layer has input shape hidden_size and output shape action_size
    def forward(self, x):
        # TODO: Implement the forward function, calling the layers you created in __init__
        # Hint: Use F.relu for the activation function
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# Note: Don't add an activation to the last layer.
#
# <details><summary>Why not?</summary>
#
# Our network needs to output a tensor that represents the quality of each action available in the agent's current state, and we don't want to put any artificial bounds on the range of possible qualities for a state-action pair.
# </details>

# %% [markdown]
# As a refresher, here's the Bellman equation from the derivation notebook:
#
# - If the current step isn't the last step:
# $$Q^{\pi}(s_t, a_t) \leftarrow \left(r_{t+1} + \underset{a \in A}{\operatorname{argmax}} Q^{\pi}(s_{t+1}, a) \right)$$
# - If the current step is the last step:
# $$Q^{\pi}(s_t, a_t) \leftarrow r_{t+1}$$

# %%
class DQN:
    def __init__(self, model, lr = 0.001, gamma = 0.99, epsilon = 0.1):
        self.model = model
        self.gamma = gamma
        self.epsilon = epsilon
        self.optimizer = t.optim.Adam(model.parameters(), lr = lr)
        self.loss = nn.MSELoss()        

    def convert_to_tensor(self, items):
        return [t.tensor(item, dtype = t.float32) for item in items]

    def train(self, state, action, next_state, reward, done):
        state, action, next_state, reward, done = self.convert_to_tensor([
            state, action, next_state, reward, done])
        
        # Here, we have a training function that takes in batches of data.
        # The arguments of the function - state, action, next_state, reward, done - are all batched tensors.

        # 1. TODO: Get the Q values of the current state and next state using the model



        # 2. TODO: Calculate the expected Q value using the Bellman equation


        
        # 3. Update the model to minimize the loss between the Q value and the expected Q value.

        """ The reason we use detach is because we don't want to propagate the gradient
         of the expected Q value - we don't want to update the model to fit the expected
         Q value to the real Q value, only the other way around."""
        loss = self.loss(q_value, expected_q_value.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def act(self, state, epsilon = None):
        epsilon = epsilon if epsilon is not None else self.epsilon
        # TODO: Implement the act function using the epsilon-greedy algorithm.

        # Explore if random number is greater than epsilon, otherwise exploit

# %% [markdown]
# In order to use a DQN, we need to discretize the action space.
# <details><summary>Why?</summary>
#
# $$Q^{\pi}(s_t, a_t) \leftarrow \left(r_{t+1} + \argmax_{a \in A} Q^{\pi}(s_{t+1}, a) \right)$$
#
# - The above update rule also only works in discretized environments, as $\argmax_{a \in A} Q^{\pi}(s_{t+1}, a)$ is intractable to calculate if there are infinite possible actions.
# </details>
#  Let us do this by dividing the range of possible actions into 4 discrete actions:
#
# - 0: [-1, 0] - Brake
# - 1: [0, -1] - Turn
# - 2: [0, 1] - Turn
# - 3: [1, 0] - Accelerate forward

# %%
def discrete_action_to_continuous(action: int):
    if action == 0:
        return [-1, 0]
    elif action == 1:
        return [0, -1]
    elif action == 2:
        return [0, 1]
    elif action == 3:
        return [1, 0]
    assert action < 4 and action > 0, "Unknown action: {}".format(action)

# %% [markdown]
# ### Replay Buffer
#
# Replay buffers, also known as experience replay, are key components in making DQNs stable and efficient. The main idea behind replay buffers is to store the agent’s experiences at each time step, then randomly draw a batch of experiences to train the network.
#
# Each experience, or transition, typically includes $s_t$, $a_t$, $r_{t_1}$, $s_{t+1}$ - the four elements necessary to update the model using the Bellman Equation, and *done*, a boolean indicating if the state is a terminal one.
#
# The use of replay buffers has several benefits:
# - Breaking the correlation between consecutive experiences: In a typical episode, consecutive experiences are highly correlated. By sampling experiences randomly from the replay buffer, we can break this correlation, which leads to more stable and effective learning.
#
# - Reusing past experiences: Without a replay buffer, an agent’s experiences would be used only once to update the network and then discarded. With a replay buffer, we can reuse past experiences, making the learning process more efficient.
#
# - Improving sample efficiency: By storing and reusing experiences, the replay buffer can help the agent learn more from fewer interactions with the environment.

# %%
class ReplayBuffer():
    def __init__(self, capacity = 10000):
        # TODO: Write the methods below to implement a replay buffer
        # Note: Once capacity is reached, the buffer should overwrite the oldest data

    def push(self, state, action, next_state, reward, done):

    def sample(self, batch_size = 32):
        # Should return a tuple of tensors with dimension [0] of batch_size in the order of:
        # return state, action, next_state, reward, done

    def __len__(self):

# %% [markdown]
# ### Training Loop

# %%
model = DQNModel()
DQNlearner = DQN(model)
replay_buffer = ReplayBuffer()

# %%
from tqdm import tqdm, trange

MAX_STEPS_PER_EPISODE = 2000
MAX_EPISODES = 1000
TRAIN_STEPS_PER_EPISODE = 50

history = []
with trange(MAX_EPISODES) as pbar:
    for ep in pbar:
        # Implement the training loop (remember to use the replay buffer!)

        # 1. TODO: Reset the environment and get the initial observation

        for i in range(MAX_STEPS_PER_EPISODE):
            # 2. TODO: Get the action using the act function of the DQN learner
            # 3. TODO: Convert the discrete action to a continuous action (using the discrete_action_to_continuous function)
            # 4. TODO: Step forward with the environment.
            # 5. TODO: Add to the training buffer.
            # 6. TODO: Stop if environment has been terminated or truncated.

        # 7. TODO: Train the DQN learner using the replay buffer once every N steps.
        # 8. Bonus TODO: Save the total reward of each episode to history.

# %%
import seaborn as sns

# Visualize the training progress (bonus)
ema_plot = []
ema = history[0]; ema_plot.append(ema)
for i in range(len(history)):
    ema = 0.9 * ema + 0.1 * history[i]
    ema_plot.append(ema)
sns.lineplot(ema_plot)
# Out:
# <Axes: >

# %% [markdown]
# ### Double Dueling DQN

# %%
import torch as t
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import copy

class DDQN:
    def __init__(self, model, lr = 0.001, gamma = 0.95, epsilon = 0.1):
        self.model = model
        self.gamma = gamma
        self.epsilon = epsilon
        self.optimizer = t.optim.Adam(model.parameters(), lr = lr)
        self.loss = nn.MSELoss()
        self.target_model = DQNModel()
        self.update_target()
        # Make the target model a copy of the original model.   

    def convert_to_tensor(self, items):
        return [t.tensor(item, dtype = t.float32) for item in items]

    def update_target(self):
        self.target_model.load_state_dict(copy.deepcopy(self.model.state_dict()))

    def train(self, state, action, next_state, reward, done):
        state, action, next_state, reward, done = self.convert_to_tensor([
            state, action, next_state, reward, done])
            
        q_values = self.model(state)
        next_q_values = self.target_model(next_state)

        # Bellman equation: Q(s,a) = r + gamma * max_a' Q(s',a')

        # First, find the Q value of the specific action we took.
        q_value = q_values.gather(1, action.unsqueeze(1).long()).squeeze(1)

        # Next, find the maximum Q value of the next state.
        next_q_value = next_q_values.max(1)[0]

        # Update the Q value of the current state using the Bellman Equation.
        expected_q_value = reward + self.gamma * next_q_value * (1 - done)

        """ The reason we use detach is because we don't want to propagate the gradient
         of the expected Q value - we don't want to update the model to fit the expected
         Q value to the real Q value, only the other way around."""
        loss = self.loss(q_value, expected_q_value.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item()

    def act(self, state, epsilon = None):
        epsilon = epsilon if epsilon is not None else self.epsilon
        if random.random() > epsilon:
            state = t.tensor(state[np.newaxis:], dtype = t.float32)
            q_value = self.model(state)
            action = q_value.argmax().item()
        else:
            action = random.randint(0, 3)
        return action

# %%
model = DQNModel()
DQNlearner = DDQN(model, lr=1e-3)
replay_buffer = ReplayBuffer()
model.load_state_dict(t.load("ddqn_trained_1000_steps"))
# Out:
# <All keys matched successfully>

# %%
from tqdm import tqdm, trange

MAX_STEPS_PER_EPISODE = 2000
MAX_EPISODES = 10000
TRAIN_STEPS_PER_EPISODE = 50
UPDATE_TARGET_EVERY = 50
BATCH_SIZE = 128

history = []
with trange(MAX_EPISODES) as pbar:
    for ep in pbar:
        total_reward = 0
        obs, info = env.reset()

        for i in range(MAX_STEPS_PER_EPISODE):
            action = DQNlearner.act(obs, epsilon=0.2)
            #action = 2
            action_continuous = discrete_action_to_continuous(action)

            new_obs, reward, terminated, truncated, info = env.step(action_continuous)
            total_reward += reward
            replay_buffer.push(obs, action, new_obs, reward, terminated)
            obs = new_obs
            if terminated or truncated:
                break

        total_loss = 0
        if len(replay_buffer) > BATCH_SIZE:
            for i in range(TRAIN_STEPS_PER_EPISODE):
                total_loss += DQNlearner.train(*replay_buffer.sample(BATCH_SIZE))

        if ep % UPDATE_TARGET_EVERY == 0:
            DQNlearner.update_target()
        
        history.append(total_reward)
        pbar.set_description(f"Episode {ep} | Reward: {round(total_reward, 4)} | Loss: {round(total_loss / TRAIN_STEPS_PER_EPISODE, 5)}")
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 0 | Reward: 13.5684 | Loss: 0.0:   0%|          | 1/10000 [00:00<1:05:42,  2.54it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 1 | Reward: 108.2919 | Loss: 3.41618:   0%|          | 2/10000 [00:01<2:52:23,  1.03s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 2 | Reward: 42.2224 | Loss: 2.78217:   0%|          | 3/10000 [00:02<2:48:59,  1.01s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 3 | Reward: 7.2641 | Loss: 3.0962:   0%|          | 4/10000 [00:03<2:22:46,  1.17it/s]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 4 | Reward: 16.863 | Loss: 2.67559:   0%|          | 5/10000 [00:04<2:10:52,  1.27it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 5 | Reward: 13.5082 | Loss: 3.00882:   0%|          | 6/10000 [00:04<2:03:03,  1.35it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 6 | Reward: 13.0758 | Loss: 3.11423:   0%|          | 7/10000 [00:05<2:01:29,  1.37it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 7 | Reward: 85.6829 | Loss: 2.63688:   0%|          | 8/10000 [00:06<2:27:20,  1.13it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 8 | Reward: 78.4714 | Loss: 2.77651:   0%|          | 9/10000 [00:07<2:37:25,  1.06it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9 | Reward: 99.0344 | Loss: 2.10899:   0%|          | 10/10000 [00:09<2:58:52,  1.07s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 10 | Reward: 72.6862 | Loss: 2.27552:   0%|          | 11/10000 [00:10<2:51:06,  1.03s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 11 | Reward: 106.6639 | Loss: 2.41822:   0%|          | 12/10000 [00:11<3:03:59,  1.11s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 12 | Reward: 92.1815 | Loss: 2.13008:   0%|          | 13/10000 [00:13<3:36:41,  1.30s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 13 | Reward: 8.1758 | Loss: 2.79287:   0%|          | 14/10000 [00:13<3:06:58,  1.12s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 14 | Reward: 19.0067 | Loss: 2.51937:   0%|          | 15/10000 [00:14<2:46:16,  1.00it/s]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 15 | Reward: 94.9934 | Loss: 2.01818:   0%|          | 16/10000 [00:16<3:22:30,  1.22s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 16 | Reward: 90.9617 | Loss: 2.33755:   0%|          | 17/10000 [00:17<3:28:53,  1.26s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 17 | Reward: 61.7846 | Loss: 2.53597:   0%|          | 18/10000 [00:18<3:13:52,  1.17s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 18 | Reward: 95.6452 | Loss: 2.77578:   0%|          | 19/10000 [00:19<3:16:40,  1.18s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 19 | Reward: 69.9242 | Loss: 2.50301:   0%|          | 20/10000 [00:20<3:04:33,  1.11s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 20 | Reward: 162.0225 | Loss: 2.06718:   0%|          | 21/10000 [00:22<3:46:42,  1.36s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 21 | Reward: 119.7582 | Loss: 1.82398:   0%|          | 22/10000 [00:24<4:05:17,  1.47s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 22 | Reward: 7.7483 | Loss: 1.99612:   0%|          | 23/10000 [00:24<3:20:24,  1.21s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 23 | Reward: 111.2616 | Loss: 1.76714:   0%|          | 24/10000 [00:26<3:31:09,  1.27s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 24 | Reward: 74.7275 | Loss: 1.77472:   0%|          | 25/10000 [00:27<3:14:30,  1.17s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 25 | Reward: 144.989 | Loss: 1.85363:   0%|          | 26/10000 [00:28<3:26:55,  1.24s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 26 | Reward: 117.7099 | Loss: 1.61021:   0%|          | 27/10000 [00:30<3:38:30,  1.31s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 27 | Reward: 98.2932 | Loss: 1.81058:   0%|          | 28/10000 [00:31<3:41:14,  1.33s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 28 | Reward: 122.1924 | Loss: 1.86998:   0%|          | 29/10000 [00:33<3:50:27,  1.39s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 29 | Reward: 163.2545 | Loss: 1.91486:   0%|          | 30/10000 [00:35<4:20:35,  1.57s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 30 | Reward: 72.8825 | Loss: 1.98411:   0%|          | 31/10000 [00:36<3:58:34,  1.44s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 31 | Reward: 97.287 | Loss: 1.66368:   0%|          | 32/10000 [00:38<4:14:13,  1.53s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 32 | Reward: 6.7084 | Loss: 1.77992:   0%|          | 33/10000 [00:38<3:27:45,  1.25s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 33 | Reward: 103.0995 | Loss: 1.99595:   0%|          | 34/10000 [00:39<3:32:59,  1.28s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 34 | Reward: 9.3833 | Loss: 2.01511:   0%|          | 35/10000 [00:41<3:35:28,  1.30s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 35 | Reward: 10.4491 | Loss: 1.82303:   0%|          | 36/10000 [00:42<3:24:06,  1.23s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 36 | Reward: 135.6392 | Loss: 1.40425:   0%|          | 37/10000 [00:44<4:05:30,  1.48s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 37 | Reward: 171.1489 | Loss: 1.41313:   0%|          | 38/10000 [00:46<4:32:10,  1.64s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 38 | Reward: 133.0585 | Loss: 1.72178:   0%|          | 39/10000 [00:48<4:30:07,  1.63s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 39 | Reward: 147.6389 | Loss: 1.61271:   0%|          | 40/10000 [00:49<4:37:59,  1.67s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 40 | Reward: 2.9828 | Loss: 1.61415:   0%|          | 41/10000 [00:50<3:42:27,  1.34s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 41 | Reward: 61.3206 | Loss: 1.72363:   0%|          | 42/10000 [00:51<3:30:05,  1.27s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 42 | Reward: 8.4113 | Loss: 2.10916:   0%|          | 43/10000 [00:52<2:57:48,  1.07s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 43 | Reward: 133.3909 | Loss: 1.43232:   0%|          | 44/10000 [00:53<3:22:32,  1.22s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 44 | Reward: 0.9798 | Loss: 1.37173:   0%|          | 45/10000 [00:54<2:48:49,  1.02s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 45 | Reward: 240.6714 | Loss: 1.70243:   0%|          | 46/10000 [00:56<3:56:30,  1.43s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 46 | Reward: 125.8346 | Loss: 2.14838:   0%|          | 47/10000 [00:58<4:04:01,  1.47s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 47 | Reward: 153.6178 | Loss: 2.00142:   0%|          | 48/10000 [01:00<4:24:42,  1.60s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 48 | Reward: 177.0442 | Loss: 1.5213:   0%|          | 49/10000 [01:02<5:23:58,  1.95s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 49 | Reward: 252.2601 | Loss: 1.75823:   0%|          | 50/10000 [01:05<6:17:08,  2.27s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 50 | Reward: 2.2764 | Loss: 1.4769:   1%|          | 51/10000 [01:06<4:52:09,  1.76s/it]   INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 51 | Reward: 121.5346 | Loss: 1.20249:   1%|          | 52/10000 [01:07<4:36:05,  1.67s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 52 | Reward: 112.1616 | Loss: 1.39231:   1%|          | 53/10000 [01:09<4:18:37,  1.56s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 53 | Reward: 116.9559 | Loss: 1.59352:   1%|          | 54/10000 [01:10<4:06:41,  1.49s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 54 | Reward: 267.4564 | Loss: 1.28968:   1%|          | 55/10000 [01:13<5:02:55,  1.83s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 55 | Reward: 119.8994 | Loss: 1.36074:   1%|          | 56/10000 [01:14<4:44:26,  1.72s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 56 | Reward: 102.5552 | Loss: 1.64175:   1%|          | 57/10000 [01:16<4:42:37,  1.71s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 57 | Reward: 166.1816 | Loss: 1.46757:   1%|          | 58/10000 [01:18<4:55:34,  1.78s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 58 | Reward: 171.1238 | Loss: 1.69194:   1%|          | 59/10000 [01:20<5:11:10,  1.88s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 59 | Reward: 173.5141 | Loss: 1.51944:   1%|          | 60/10000 [01:22<5:13:53,  1.89s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 60 | Reward: 261.4425 | Loss: 1.76629:   1%|          | 61/10000 [01:24<5:27:56,  1.98s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 61 | Reward: 7.0379 | Loss: 1.58274:   1%|          | 62/10000 [01:25<4:19:40,  1.57s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 62 | Reward: 79.1738 | Loss: 1.63586:   1%|          | 63/10000 [01:26<4:14:36,  1.54s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 63 | Reward: 90.67 | Loss: 1.76889:   1%|          | 64/10000 [01:27<3:53:13,  1.41s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 64 | Reward: 135.0116 | Loss: 1.19084:   1%|          | 65/10000 [01:29<4:03:08,  1.47s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 65 | Reward: 121.2593 | Loss: 1.53448:   1%|          | 66/10000 [01:30<4:11:44,  1.52s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 66 | Reward: 108.9578 | Loss: 1.37586:   1%|          | 67/10000 [01:32<3:56:32,  1.43s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 67 | Reward: 127.4245 | Loss: 1.08258:   1%|          | 68/10000 [01:34<4:29:20,  1.63s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 68 | Reward: 144.3014 | Loss: 1.69653:   1%|          | 69/10000 [01:36<4:40:52,  1.70s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 69 | Reward: 78.2324 | Loss: 1.23405:   1%|          | 70/10000 [01:36<4:03:07,  1.47s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 70 | Reward: 132.1944 | Loss: 1.39736:   1%|          | 71/10000 [01:39<4:39:37,  1.69s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 71 | Reward: 2.691 | Loss: 1.21346:   1%|          | 72/10000 [01:39<3:46:53,  1.37s/it]   INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 72 | Reward: 75.692 | Loss: 1.28335:   1%|          | 73/10000 [01:40<3:24:41,  1.24s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 73 | Reward: 112.2493 | Loss: 1.40479:   1%|          | 74/10000 [01:41<3:25:40,  1.24s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 74 | Reward: 104.8019 | Loss: 1.61223:   1%|          | 75/10000 [01:43<3:34:49,  1.30s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 75 | Reward: 113.6783 | Loss: 1.22407:   1%|          | 76/10000 [01:44<3:42:15,  1.34s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 76 | Reward: 135.4262 | Loss: 1.52098:   1%|          | 77/10000 [01:46<3:47:34,  1.38s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 77 | Reward: 117.0321 | Loss: 1.485:   1%|          | 78/10000 [01:48<4:03:56,  1.48s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 78 | Reward: 101.9398 | Loss: 1.44501:   1%|          | 79/10000 [01:49<3:42:55,  1.35s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 79 | Reward: 161.9848 | Loss: 1.17913:   1%|          | 80/10000 [01:51<4:19:04,  1.57s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 80 | Reward: 125.1211 | Loss: 1.16596:   1%|          | 81/10000 [01:52<4:23:42,  1.60s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 81 | Reward: 163.3345 | Loss: 1.34901:   1%|          | 82/10000 [01:54<4:24:10,  1.60s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 82 | Reward: -1.7038 | Loss: 1.2045:   1%|          | 83/10000 [01:55<3:51:11,  1.40s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 83 | Reward: 8.2826 | Loss: 1.34298:   1%|          | 84/10000 [01:55<3:12:08,  1.16s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 84 | Reward: 155.9455 | Loss: 1.20195:   1%|          | 85/10000 [01:57<3:47:10,  1.37s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 85 | Reward: 88.4717 | Loss: 1.44564:   1%|          | 86/10000 [01:58<3:27:21,  1.25s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 86 | Reward: 62.7044 | Loss: 1.52265:   1%|          | 87/10000 [01:59<3:08:12,  1.14s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 87 | Reward: 134.6825 | Loss: 1.06019:   1%|          | 88/10000 [02:01<3:43:14,  1.35s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 88 | Reward: 115.6129 | Loss: 1.23529:   1%|          | 89/10000 [02:02<3:47:21,  1.38s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 89 | Reward: 115.5651 | Loss: 1.40183:   1%|          | 90/10000 [02:04<3:47:01,  1.37s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 90 | Reward: 131.8389 | Loss: 1.76059:   1%|          | 91/10000 [02:05<3:51:25,  1.40s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 91 | Reward: 150.0988 | Loss: 1.4363:   1%|          | 92/10000 [02:07<4:00:48,  1.46s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 92 | Reward: 135.2322 | Loss: 1.20276:   1%|          | 93/10000 [02:08<3:59:52,  1.45s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 93 | Reward: 129.1122 | Loss: 1.34664:   1%|          | 94/10000 [02:10<3:56:51,  1.43s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 94 | Reward: 149.4418 | Loss: 1.43197:   1%|          | 95/10000 [02:11<4:11:58,  1.53s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 95 | Reward: 52.4177 | Loss: 1.33271:   1%|          | 96/10000 [02:12<3:44:18,  1.36s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 96 | Reward: 169.1035 | Loss: 1.07992:   1%|          | 97/10000 [02:14<3:54:18,  1.42s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 97 | Reward: 33.4283 | Loss: 1.33221:   1%|          | 98/10000 [02:15<3:19:11,  1.21s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 98 | Reward: 77.493 | Loss: 1.27809:   1%|          | 99/10000 [02:16<3:07:22,  1.14s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 99 | Reward: 152.9418 | Loss: 1.17747:   1%|          | 100/10000 [02:17<3:23:46,  1.23s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 100 | Reward: 107.1762 | Loss: 1.02485:   1%|          | 101/10000 [02:18<3:21:09,  1.22s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 101 | Reward: 153.7706 | Loss: 1.5279:   1%|          | 102/10000 [02:20<3:50:51,  1.40s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 102 | Reward: 125.9046 | Loss: 1.54683:   1%|          | 103/10000 [02:22<3:52:44,  1.41s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 103 | Reward: 127.2493 | Loss: 1.40964:   1%|          | 104/10000 [02:23<4:02:37,  1.47s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 104 | Reward: 61.3071 | Loss: 1.46021:   1%|          | 105/10000 [02:24<3:35:52,  1.31s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 105 | Reward: 120.1002 | Loss: 1.45824:   1%|          | 106/10000 [02:26<3:47:27,  1.38s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 106 | Reward: 141.275 | Loss: 1.53989:   1%|          | 107/10000 [02:27<3:59:00,  1.45s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 107 | Reward: 72.7879 | Loss: 2.16152:   1%|          | 108/10000 [02:28<3:35:41,  1.31s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 108 | Reward: 88.386 | Loss: 1.88636:   1%|          | 109/10000 [02:29<3:23:28,  1.23s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 109 | Reward: 128.3457 | Loss: 1.20058:   1%|          | 110/10000 [02:31<3:23:23,  1.23s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 110 | Reward: 270.6037 | Loss: 1.81635:   1%|          | 111/10000 [02:33<4:14:19,  1.54s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 111 | Reward: 116.555 | Loss: 1.61631:   1%|          | 112/10000 [02:34<4:04:47,  1.49s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 112 | Reward: 90.1445 | Loss: 1.54488:   1%|          | 113/10000 [02:35<3:45:32,  1.37s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 113 | Reward: 80.0627 | Loss: 1.50808:   1%|          | 114/10000 [02:36<3:29:31,  1.27s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 114 | Reward: 137.9625 | Loss: 1.54841:   1%|          | 115/10000 [02:38<3:34:00,  1.30s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 115 | Reward: 76.1519 | Loss: 1.38497:   1%|          | 116/10000 [02:39<3:15:27,  1.19s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 116 | Reward: 68.0462 | Loss: 1.34271:   1%|          | 117/10000 [02:40<3:09:24,  1.15s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 117 | Reward: 8.3988 | Loss: 1.58424:   1%|          | 118/10000 [02:40<2:40:28,  1.03it/s] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 118 | Reward: 121.9756 | Loss: 1.74215:   1%|          | 119/10000 [02:41<2:55:05,  1.06s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 119 | Reward: 124.5702 | Loss: 1.81189:   1%|          | 120/10000 [02:43<3:13:01,  1.17s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 120 | Reward: 117.5356 | Loss: 1.60794:   1%|          | 121/10000 [02:44<3:28:17,  1.27s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 121 | Reward: 116.4346 | Loss: 1.84545:   1%|          | 122/10000 [02:46<3:37:13,  1.32s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 122 | Reward: 133.9624 | Loss: 1.26632:   1%|          | 123/10000 [02:47<3:45:56,  1.37s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 123 | Reward: 89.4557 | Loss: 1.33733:   1%|          | 124/10000 [02:48<3:33:41,  1.30s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 124 | Reward: 168.3406 | Loss: 1.52013:   1%|▏         | 125/10000 [02:50<3:47:54,  1.38s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 125 | Reward: 273.8069 | Loss: 1.32842:   1%|▏         | 126/10000 [02:52<4:35:41,  1.68s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 126 | Reward: 124.7501 | Loss: 1.36531:   1%|▏         | 127/10000 [02:54<4:22:22,  1.59s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 127 | Reward: 107.474 | Loss: 1.52767:   1%|▏         | 128/10000 [02:55<4:10:34,  1.52s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 128 | Reward: 60.1843 | Loss: 1.70924:   1%|▏         | 129/10000 [02:56<3:39:12,  1.33s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 129 | Reward: 134.9034 | Loss: 1.61052:   1%|▏         | 130/10000 [02:58<3:50:16,  1.40s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 130 | Reward: 130.206 | Loss: 1.50401:   1%|▏         | 131/10000 [02:59<4:13:26,  1.54s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 131 | Reward: 90.5038 | Loss: 1.64574:   1%|▏         | 132/10000 [03:01<4:10:33,  1.52s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 132 | Reward: 132.0798 | Loss: 1.42913:   1%|▏         | 133/10000 [03:02<4:10:33,  1.52s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 133 | Reward: 107.2376 | Loss: 1.44151:   1%|▏         | 134/10000 [03:04<3:59:07,  1.45s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 134 | Reward: 268.3871 | Loss: 1.2259:   1%|▏         | 135/10000 [03:06<5:00:49,  1.83s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 135 | Reward: 145.0884 | Loss: 1.61213:   1%|▏         | 136/10000 [03:08<4:50:48,  1.77s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 136 | Reward: 115.8558 | Loss: 1.41036:   1%|▏         | 137/10000 [03:09<4:19:14,  1.58s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 137 | Reward: 141.2034 | Loss: 1.47952:   1%|▏         | 138/10000 [03:11<4:20:03,  1.58s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 138 | Reward: 92.9025 | Loss: 1.63217:   1%|▏         | 139/10000 [03:12<4:01:44,  1.47s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 139 | Reward: 123.4492 | Loss: 1.43124:   1%|▏         | 140/10000 [03:13<3:58:03,  1.45s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 140 | Reward: 132.9587 | Loss: 1.40841:   1%|▏         | 141/10000 [03:15<3:55:50,  1.44s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 141 | Reward: 121.4678 | Loss: 1.30505:   1%|▏         | 142/10000 [03:16<4:03:28,  1.48s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 142 | Reward: 151.9042 | Loss: 1.62564:   1%|▏         | 143/10000 [03:18<4:11:38,  1.53s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 143 | Reward: 128.165 | Loss: 1.39536:   1%|▏         | 144/10000 [03:19<4:05:34,  1.49s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 144 | Reward: 110.726 | Loss: 1.516:   1%|▏         | 145/10000 [03:21<3:50:17,  1.40s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 145 | Reward: 117.4293 | Loss: 1.64462:   1%|▏         | 146/10000 [03:22<3:57:04,  1.44s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 146 | Reward: 99.7743 | Loss: 1.34756:   1%|▏         | 147/10000 [03:23<3:46:50,  1.38s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 147 | Reward: 91.0334 | Loss: 1.26177:   1%|▏         | 148/10000 [03:25<3:34:09,  1.30s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 148 | Reward: 92.8986 | Loss: 1.55903:   1%|▏         | 149/10000 [03:26<3:19:50,  1.22s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 149 | Reward: 133.2413 | Loss: 1.52345:   2%|▏         | 150/10000 [03:27<3:28:44,  1.27s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 150 | Reward: 271.1902 | Loss: 1.37273:   2%|▏         | 151/10000 [03:29<4:20:20,  1.59s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 151 | Reward: 277.8104 | Loss: 1.24861:   2%|▏         | 152/10000 [03:32<4:54:45,  1.80s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 152 | Reward: 111.9215 | Loss: 1.69937:   2%|▏         | 153/10000 [03:33<4:22:48,  1.60s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 153 | Reward: 4.2924 | Loss: 1.21158:   2%|▏         | 154/10000 [03:33<3:32:41,  1.30s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 154 | Reward: 137.7433 | Loss: 1.74879:   2%|▏         | 155/10000 [03:35<4:02:51,  1.48s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 155 | Reward: 102.4029 | Loss: 1.6982:   2%|▏         | 156/10000 [03:36<3:43:18,  1.36s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 156 | Reward: 141.9553 | Loss: 1.45571:   2%|▏         | 157/10000 [03:38<4:13:59,  1.55s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 157 | Reward: 115.6521 | Loss: 1.5964:   2%|▏         | 158/10000 [03:40<4:01:31,  1.47s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 158 | Reward: 117.0813 | Loss: 1.48683:   2%|▏         | 159/10000 [03:41<4:12:48,  1.54s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 159 | Reward: 143.5764 | Loss: 1.28787:   2%|▏         | 160/10000 [03:43<4:05:49,  1.50s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 160 | Reward: 124.8769 | Loss: 1.33757:   2%|▏         | 161/10000 [03:44<4:05:38,  1.50s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 161 | Reward: 123.9172 | Loss: 1.39164:   2%|▏         | 162/10000 [03:46<4:03:09,  1.48s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 162 | Reward: 373.4222 | Loss: 1.69229:   2%|▏         | 163/10000 [03:50<6:29:43,  2.38s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 163 | Reward: 125.0377 | Loss: 1.40028:   2%|▏         | 164/10000 [03:52<5:59:49,  2.19s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 164 | Reward: 124.6131 | Loss: 1.32152:   2%|▏         | 165/10000 [03:54<5:39:17,  2.07s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 165 | Reward: 114.5488 | Loss: 1.23129:   2%|▏         | 166/10000 [03:55<5:00:40,  1.83s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 166 | Reward: 133.2473 | Loss: 1.10083:   2%|▏         | 167/10000 [03:57<4:48:59,  1.76s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 167 | Reward: 151.8311 | Loss: 1.1636:   2%|▏         | 168/10000 [03:59<5:03:26,  1.85s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 168 | Reward: 282.0068 | Loss: 0.79682:   2%|▏         | 169/10000 [04:01<5:44:38,  2.10s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 169 | Reward: 9.2811 | Loss: 1.03989:   2%|▏         | 170/10000 [04:02<4:30:02,  1.65s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 170 | Reward: 169.6077 | Loss: 0.90574:   2%|▏         | 171/10000 [04:04<4:58:21,  1.82s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 171 | Reward: 180.1184 | Loss: 1.27761:   2%|▏         | 172/10000 [04:06<5:12:58,  1.91s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 172 | Reward: 178.5755 | Loss: 1.10708:   2%|▏         | 173/10000 [04:08<5:23:12,  1.97s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 173 | Reward: 3.0603 | Loss: 1.51614:   2%|▏         | 174/10000 [04:09<4:13:12,  1.55s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 174 | Reward: 166.5232 | Loss: 1.58511:   2%|▏         | 175/10000 [04:11<4:23:43,  1.61s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 175 | Reward: 6.4608 | Loss: 1.03512:   2%|▏         | 176/10000 [04:11<3:33:10,  1.30s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 176 | Reward: 157.1249 | Loss: 1.12163:   2%|▏         | 177/10000 [04:13<3:54:44,  1.43s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 177 | Reward: 141.7727 | Loss: 0.9655:   2%|▏         | 178/10000 [04:15<4:06:12,  1.50s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 178 | Reward: 134.8194 | Loss: 0.91831:   2%|▏         | 179/10000 [04:16<4:10:21,  1.53s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 179 | Reward: 130.1508 | Loss: 1.10817:   2%|▏         | 180/10000 [04:18<4:13:21,  1.55s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 180 | Reward: 147.3201 | Loss: 0.94181:   2%|▏         | 181/10000 [04:19<4:10:43,  1.53s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 181 | Reward: 158.6864 | Loss: 1.15324:   2%|▏         | 182/10000 [04:21<4:40:10,  1.71s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 182 | Reward: 139.5005 | Loss: 1.06223:   2%|▏         | 183/10000 [04:23<4:38:27,  1.70s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 183 | Reward: 9.4567 | Loss: 1.43148:   2%|▏         | 184/10000 [04:24<3:45:00,  1.38s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 184 | Reward: 135.4865 | Loss: 0.92692:   2%|▏         | 185/10000 [04:25<3:47:38,  1.39s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 185 | Reward: 274.9213 | Loss: 1.17405:   2%|▏         | 186/10000 [04:28<4:54:31,  1.80s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 186 | Reward: 103.7724 | Loss: 1.12897:   2%|▏         | 187/10000 [04:29<4:35:51,  1.69s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 187 | Reward: 133.8055 | Loss: 1.07013:   2%|▏         | 188/10000 [04:31<4:33:45,  1.67s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 188 | Reward: 179.9405 | Loss: 1.16022:   2%|▏         | 189/10000 [04:33<5:02:01,  1.85s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 189 | Reward: 9.195 | Loss: 0.93204:   2%|▏         | 190/10000 [04:34<3:58:49,  1.46s/it]   INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 190 | Reward: 136.35 | Loss: 1.10325:   2%|▏         | 191/10000 [04:36<4:13:30,  1.55s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 191 | Reward: 149.4549 | Loss: 1.15132:   2%|▏         | 192/10000 [04:37<4:21:24,  1.60s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 192 | Reward: 136.4856 | Loss: 1.19041:   2%|▏         | 193/10000 [04:39<4:20:08,  1.59s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 193 | Reward: 279.7392 | Loss: 1.11011:   2%|▏         | 194/10000 [04:42<5:15:26,  1.93s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 194 | Reward: 278.2401 | Loss: 0.9345:   2%|▏         | 195/10000 [04:44<5:48:07,  2.13s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 195 | Reward: 161.5097 | Loss: 0.82822:   2%|▏         | 196/10000 [04:46<5:23:13,  1.98s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 196 | Reward: 287.6056 | Loss: 0.91625:   2%|▏         | 197/10000 [04:49<6:20:45,  2.33s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# ...
# Episode 9934 | Reward: 137.1933 | Loss: 1.62082:  99%|█████████▉| 9935/10000 [5:51:19<01:54,  1.77s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9935 | Reward: 167.3735 | Loss: 1.91925:  99%|█████████▉| 9936/10000 [5:51:21<01:54,  1.79s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9936 | Reward: 47.1252 | Loss: 2.19562:  99%|█████████▉| 9937/10000 [5:51:22<01:39,  1.58s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9937 | Reward: 156.4048 | Loss: 1.76255:  99%|█████████▉| 9938/10000 [5:51:25<01:59,  1.93s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9938 | Reward: 225.8331 | Loss: 1.13088:  99%|█████████▉| 9939/10000 [5:51:27<02:05,  2.06s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9939 | Reward: 71.8056 | Loss: 1.82939:  99%|█████████▉| 9940/10000 [5:51:28<01:47,  1.80s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9940 | Reward: 133.0434 | Loss: 1.59668:  99%|█████████▉| 9941/10000 [5:51:30<01:41,  1.72s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9941 | Reward: 132.0132 | Loss: 1.79732:  99%|█████████▉| 9942/10000 [5:51:32<01:40,  1.74s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9942 | Reward: 115.3674 | Loss: 2.23781:  99%|█████████▉| 9943/10000 [5:51:33<01:32,  1.62s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9943 | Reward: 12.7027 | Loss: 1.95294:  99%|█████████▉| 9944/10000 [5:51:34<01:16,  1.36s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9944 | Reward: 150.1024 | Loss: 1.9495:  99%|█████████▉| 9945/10000 [5:51:36<01:22,  1.50s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9945 | Reward: 282.3137 | Loss: 1.73143:  99%|█████████▉| 9946/10000 [5:51:39<01:45,  1.95s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9946 | Reward: 8.5687 | Loss: 1.91955:  99%|█████████▉| 9947/10000 [5:51:39<01:25,  1.62s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9947 | Reward: 7.1092 | Loss: 1.76838:  99%|█████████▉| 9948/10000 [5:51:40<01:09,  1.34s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9948 | Reward: 156.918 | Loss: 1.77198:  99%|█████████▉| 9949/10000 [5:51:42<01:19,  1.56s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9949 | Reward: 150.8498 | Loss: 1.86771: 100%|█████████▉| 9950/10000 [5:51:44<01:26,  1.74s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9950 | Reward: 11.0131 | Loss: 1.21192: 100%|█████████▉| 9951/10000 [5:51:45<01:10,  1.44s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9951 | Reward: 224.8396 | Loss: 1.88496: 100%|█████████▉| 9952/10000 [5:51:48<01:27,  1.83s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9952 | Reward: 164.027 | Loss: 1.50568: 100%|█████████▉| 9953/10000 [5:51:50<01:27,  1.86s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9953 | Reward: 156.5238 | Loss: 1.46512: 100%|█████████▉| 9954/10000 [5:51:52<01:27,  1.90s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9954 | Reward: 172.5699 | Loss: 1.59231: 100%|█████████▉| 9955/10000 [5:51:54<01:29,  2.00s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9955 | Reward: 13.7449 | Loss: 1.5859: 100%|█████████▉| 9956/10000 [5:51:55<01:12,  1.65s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9956 | Reward: 175.8571 | Loss: 1.38778: 100%|█████████▉| 9957/10000 [5:51:57<01:14,  1.74s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9957 | Reward: 162.9081 | Loss: 1.8975: 100%|█████████▉| 9958/10000 [5:51:59<01:14,  1.78s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9958 | Reward: 161.9529 | Loss: 1.16454: 100%|█████████▉| 9959/10000 [5:52:00<01:13,  1.79s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9959 | Reward: 282.9128 | Loss: 1.70188: 100%|█████████▉| 9960/10000 [5:52:03<01:27,  2.18s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9960 | Reward: 158.0062 | Loss: 2.09623: 100%|█████████▉| 9961/10000 [5:52:05<01:19,  2.05s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: crash vehicle
# Episode 9961 | Reward: 331.6563 | Loss: 2.30133: 100%|█████████▉| 9962/10000 [5:52:09<01:32,  2.44s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9962 | Reward: 155.0591 | Loss: 1.32368: 100%|█████████▉| 9963/10000 [5:52:10<01:20,  2.17s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9963 | Reward: 153.7973 | Loss: 1.61766: 100%|█████████▉| 9964/10000 [5:52:12<01:13,  2.03s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9964 | Reward: 156.1269 | Loss: 1.76673: 100%|█████████▉| 9965/10000 [5:52:14<01:08,  1.95s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9966 | Reward: 165.0511 | Loss: 1.60485: 100%|█████████▉| 9967/10000 [5:52:29<02:55,  5.32s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9967 | Reward: 162.5452 | Loss: 1.35533: 100%|█████████▉| 9968/10000 [5:52:31<02:18,  4.32s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9968 | Reward: 289.7816 | Loss: 1.31037: 100%|█████████▉| 9969/10000 [5:52:34<02:01,  3.92s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9969 | Reward: 278.0567 | Loss: 1.0294: 100%|█████████▉| 9970/10000 [5:52:37<01:49,  3.66s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9970 | Reward: 191.9097 | Loss: 1.00856: 100%|█████████▉| 9971/10000 [5:52:39<01:34,  3.27s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9971 | Reward: 286.954 | Loss: 1.43636: 100%|█████████▉| 9972/10000 [5:52:42<01:25,  3.04s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9972 | Reward: 165.2253 | Loss: 1.03267: 100%|█████████▉| 9973/10000 [5:52:43<01:12,  2.69s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9973 | Reward: 293.4827 | Loss: 1.28839: 100%|█████████▉| 9974/10000 [5:52:48<01:21,  3.15s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9974 | Reward: 153.5131 | Loss: 1.25356: 100%|█████████▉| 9975/10000 [5:52:49<01:08,  2.75s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9975 | Reward: 289.0851 | Loss: 1.17723: 100%|█████████▉| 9976/10000 [5:52:52<01:07,  2.82s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9976 | Reward: 174.7361 | Loss: 1.27558: 100%|█████████▉| 9977/10000 [5:52:55<01:00,  2.62s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9977 | Reward: 16.8656 | Loss: 0.93923: 100%|█████████▉| 9978/10000 [5:52:56<00:46,  2.12s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9978 | Reward: 177.4614 | Loss: 1.43539: 100%|█████████▉| 9979/10000 [5:52:58<00:44,  2.13s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9979 | Reward: 119.1133 | Loss: 1.13707: 100%|█████████▉| 9980/10000 [5:52:59<00:38,  1.90s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9980 | Reward: 160.8168 | Loss: 1.61513: 100%|█████████▉| 9981/10000 [5:53:02<00:39,  2.06s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9981 | Reward: 173.7718 | Loss: 1.11608: 100%|█████████▉| 9982/10000 [5:53:03<00:36,  2.01s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9982 | Reward: 137.9674 | Loss: 1.01508: 100%|█████████▉| 9983/10000 [5:53:05<00:32,  1.90s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9983 | Reward: 19.7612 | Loss: 1.27759: 100%|█████████▉| 9984/10000 [5:53:06<00:25,  1.57s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9984 | Reward: 180.8913 | Loss: 1.17697: 100%|█████████▉| 9985/10000 [5:53:08<00:26,  1.78s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9985 | Reward: 7.0552 | Loss: 1.48782: 100%|█████████▉| 9986/10000 [5:53:09<00:20,  1.47s/it]  INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9986 | Reward: 160.4962 | Loss: 1.56912: 100%|█████████▉| 9987/10000 [5:53:11<00:22,  1.73s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9987 | Reward: 171.191 | Loss: 1.46863: 100%|█████████▉| 9988/10000 [5:53:13<00:21,  1.79s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9988 | Reward: 81.3943 | Loss: 1.39961: 100%|█████████▉| 9989/10000 [5:53:14<00:17,  1.63s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9989 | Reward: 164.7544 | Loss: 1.41888: 100%|█████████▉| 9990/10000 [5:53:17<00:19,  1.96s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9990 | Reward: 160.8689 | Loss: 0.94595: 100%|█████████▉| 9991/10000 [5:53:19<00:17,  1.99s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9991 | Reward: 147.4189 | Loss: 1.34802: 100%|█████████▉| 9992/10000 [5:53:22<00:17,  2.19s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9992 | Reward: 146.9722 | Loss: 1.2828: 100%|█████████▉| 9993/10000 [5:53:24<00:14,  2.12s/it] INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9993 | Reward: 283.7586 | Loss: 1.22755: 100%|█████████▉| 9994/10000 [5:53:27<00:14,  2.49s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9994 | Reward: 135.0656 | Loss: 1.08033: 100%|█████████▉| 9995/10000 [5:53:29<00:11,  2.24s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9995 | Reward: 163.0477 | Loss: 1.14861: 100%|█████████▉| 9996/10000 [5:53:31<00:08,  2.18s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9996 | Reward: 172.1294 | Loss: 1.11371: 100%|█████████▉| 9997/10000 [5:53:33<00:06,  2.14s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9997 | Reward: 155.6419 | Loss: 0.96235: 100%|█████████▉| 9998/10000 [5:53:35<00:04,  2.09s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9998 | Reward: 143.6311 | Loss: 1.20017: 100%|█████████▉| 9999/10000 [5:53:37<00:01,  1.97s/it]INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
# Episode 9999 | Reward: 46.9924 | Loss: 1.13225: 100%|██████████| 10000/10000 [5:53:38<00:00,  2.12s/it]

# %%
model(t.tensor(obs[np.newaxis:], dtype = t.float32))
# Out:
# tensor([8.7031, 5.6386, 4.9396, 1.1610], grad_fn=<AddBackward0>)

# %%
import seaborn as sns
ema_plot = []
ema = history[0]; ema_plot.append(ema)
for i in range(len(history)):
    ema = 0.9 * ema + 0.1 * history[i]
    ema_plot.append(ema)
sns.lineplot(ema_plot[:600])
# Out:
# <Axes: >

# %% [markdown]
# ## Inference

# %%
import metadrive  # Import this package to register the environment!
import gymnasium as gym

env = gym.make("MetaDrive-validation-v0", config={"use_render": True})

# Alternatively, you can instantiate using the class
# env = metadrive.MetaDriveEnv(config={"use_render": True, "num_scenarios": 100})
# Out:
# Successfully registered the following environments: ['MetaDrive-validation-v0', 'MetaDrive-10env-v0', 'MetaDrive-100envs-v0', 'MetaDrive-1000envs-v0', 'SafeMetaDrive-validation-v0', 'SafeMetaDrive-10env-v0', 'SafeMetaDrive-100envs-v0', 'SafeMetaDrive-1000envs-v0', 'MARLTollgate-v0', 'MARLBottleneck-v0', 'MARLRoundabout-v0', 'MARLIntersection-v0', 'MARLParkingLot-v0', 'MARLMetaDrive-v0'].

# %%
model = DQNModel()
model.load_state_dict(t.load("ddqn_trained_1000_steps"))
DQNlearner = DDQN(model)

# %%
from tqdm import tqdm, trange

MAX_STEPS_PER_EPISODE = 10000
total_reward = 0
obs, info = env.reset()
for i in range(MAX_STEPS_PER_EPISODE):
    action = DQNlearner.act(obs, epsilon = 0.3)
    action_continuous = discrete_action_to_continuous(action)
    obs, reward, terminated, truncated, info = env.step(action_continuous)
    total_reward += reward

    if terminated or truncated:
        break
# Out:
# INFO:c:\Users\william\Desktop\Software\Development\Projects\metadrive\metadrive\metadrive\envs\base_env.py:Episode ended! Reason: out_of_road.
